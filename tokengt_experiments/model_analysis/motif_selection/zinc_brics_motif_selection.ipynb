# %%
import pandas as pd
import numpy as np
from rdkit import Chem
from rdkit.Chem import AllChem
from collections import defaultdict
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm import tqdm
import warnings
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter, MaxNLocator, PercentFormatter
from matplotlib.patches import Patch

from tokengt_paper_repo.pcqm4mv2_pyg import PygPCQM4Mv2Dataset
from torch_geometric.loader import DataLoader

from tokengt_experiments.motif_selection.zinc_smiles_dataset import ZincSmilesDataset
from rdkit import Chem
from rdkit.Chem import BRICS

import torch
import random

warnings.filterwarnings('ignore')

# Suppress RDKit warnings
import rdkit
lg = rdkit.RDLogger.logger()
lg.setLevel(rdkit.RDLogger.CRITICAL)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 18
#      15 from tokengt_paper_repo.pcqm4mv2_pyg import PygPCQM4Mv2Dataset
#      16 from torch_geometric.loader import DataLoader
# ---> 18 from tokengt_experiments.motif_selection.zinc_smiles_dataset import ZincSmilesDataset
#      19 from rdkit import Chem
#      20 from rdkit.Chem import BRICS
#
# ModuleNotFoundError: No module named 'tokengt_experiments.motif_selection'

# %%
mol = Chem.MolFromSmiles("CC(=O)OC1=CC=CC=C1C(=O)O")  # aspirin
frags = BRICS.BRICSDecompose(mol)                     # returns a set of fragment SMILES with * attachment points
print(frags)

# Break the molecule at BRICS bonds:
mol_broken = BRICS.BreakBRICSBonds(mol)

# Split into disconnected fragments:
parts = Chem.GetMolFrags(mol_broken, asMols=True, sanitizeFrags=True)

def remove_dummy_atoms(mol):
    em = Chem.EditableMol(mol)
    dummy_atoms = [a.GetIdx() for a in mol.GetAtoms() if a.GetAtomicNum() == 0]
    for idx in reversed(dummy_atoms):  # delete in reverse order to keep indices valid
        em.RemoveAtom(idx)
    return em.GetMol()

frag_smiles = [Chem.MolToSmiles(remove_dummy_atoms(p), canonical=True) for p in parts]
print(frag_smiles)
# Out:
# {'[16*]c1ccccc1[16*]', '[6*]C(=O)O', '[1*]C(C)=O', '[3*]O[3*]'}
# ['CC=O', 'O', 'c1ccccc1', 'O=CO']

# %%
num_molecules = 10000
min_motif_size = 2
min_motif_frequency = 0.1

dataset = ZincSmilesDataset(root="data/zinc/", split="train", subset=True)
indices = random.sample(range(len(dataset)), num_molecules)
mol_smiles = [dataset[i].smiles for i in indices]
molecules = [Chem.MolFromSmiles(smiles) for smiles in mol_smiles]

# %%
all_smiles = set()

for mol in tqdm(molecules):
    mol_broken = BRICS.BreakBRICSBonds(mol)
    parts = Chem.GetMolFrags(mol_broken, asMols=True, sanitizeFrags=True)
    frag_smiles = [Chem.MolToSmiles(remove_dummy_atoms(p), canonical=True) for p in parts]
    all_smiles.update(frag_smiles)

len(all_smiles)
# Out:
# 100%|██████████| 10000/10000 [01:03<00:00, 157.26it/s]
# 4127

# %%
motif_smiles = list(all_smiles)
motifs = [Chem.MolFromSmiles(smiles) for smiles in motif_smiles if Chem.MolFromSmiles(smiles) is not None]
motif_smiles = [smiles for smiles in motif_smiles if Chem.MolFromSmiles(smiles) is not None]
[molecules[i].GetSubstructMatches(motifs[1]) for i in range(len(molecules))]
len(molecules), len(motifs), len(motif_smiles)
# Out:
# (10000, 3807, 3807)

# %%
def find_motif_matches(molecules, motif_mols, motif_smiles):
    results = defaultdict(list)

    for mol_idx, mol in enumerate(tqdm(molecules, desc="Processing molecules")):
        for motif_idx, motif_mol in enumerate(motif_mols):
            matches = mol.GetSubstructMatches(motif_mol)
            
            if matches:
                results[motif_smiles[motif_idx]].append({
                    'molecule_idx': mol_idx,
                    'num_matches': len(matches),
                    'match_positions': matches
                })
    
    return results


def analyze_motif_frequency(match_results, num_molecules):
    motif_stats = {}
    
    for motif_smiles, matches in match_results.items():
        molecules_with_motif = len(set(match['molecule_idx'] for match in matches))
        total_matches = sum(match['num_matches'] for match in matches)
        motif_stats[motif_smiles] = {
            'frequency': molecules_with_motif / num_molecules,
            'total_matches': total_matches,
            'avg_matches_per_mol': total_matches / molecules_with_motif if molecules_with_motif > 0 else 0,
            'molecules_with_motif': molecules_with_motif
        }
    
    return motif_stats

# %%
match_results = find_motif_matches(molecules, motifs, motif_smiles)
motif_stats = analyze_motif_frequency(match_results, len(molecules))
motif_stats
# Out:
# Processing molecules: 100%|██████████| 10000/10000 [03:45<00:00, 44.43it/s]
# {'Clc1ccccc1': {'frequency': 0.116,
#   'total_matches': 1341,
#   'avg_matches_per_mol': 1.1560344827586206,
#   'molecules_with_motif': 1160},
#  'S': {'frequency': 0.3501,
#   'total_matches': 4100,
#   'avg_matches_per_mol': 1.1710939731505283,
#   'molecules_with_motif': 3501},
#  'C/C(Cl)=C/Cl': {'frequency': 0.0001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'CCl': {'frequency': 0.144,
#   'total_matches': 1682,
#   'avg_matches_per_mol': 1.1680555555555556,
#   'molecules_with_motif': 1440},
#  'CN': {'frequency': 0.9444,
#   'total_matches': 39008,
#   'avg_matches_per_mol': 4.130453197797544,
#   'molecules_with_motif': 9444},
#  'N': {'frequency': 0.9767,
#   'total_matches': 28349,
#   'avg_matches_per_mol': 2.902528923927511,
#   'molecules_with_motif': 9767},
#  'Nc1ccc(Cl)cc1': {'frequency': 0.0154,
#   'total_matches': 154,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 154},
#  'C': {'frequency': 1.0,
#   'total_matches': 170895,
#   'avg_matches_per_mol': 17.0895,
#   'molecules_with_motif': 10000},
#  'C=CC': {'frequency': 0.0857,
#   'total_matches': 2096,
#   'avg_matches_per_mol': 2.4457409568261377,
#   'molecules_with_motif': 857},
#  'Nc1ccccc1': {'frequency': 0.3248,
#   'total_matches': 3951,
#   'avg_matches_per_mol': 1.2164408866995073,
#   'molecules_with_motif': 3248},
#  'CCS': {'frequency': 0.1407,
#   'total_matches': 2459,
#   'avg_matches_per_mol': 1.747690120824449,
#   'molecules_with_motif': 1407},
#  'CS': {'frequency': 0.223,
#   'total_matches': 3948,
#   'avg_matches_per_mol': 1.770403587443946,
#   'molecules_with_motif': 2230},
#  'c1ccccc1': {'frequency': 0.77,
#   'total_matches': 10682,
#   'avg_matches_per_mol': 1.3872727272727272,
#   'molecules_with_motif': 7700},
#  'CCCl': {'frequency': 0.0066,
#   'total_matches': 105,
#   'avg_matches_per_mol': 1.5909090909090908,
#   'molecules_with_motif': 66},
#  'CC': {'frequency': 0.9966,
#   'total_matches': 65466,
#   'avg_matches_per_mol': 6.568934376881397,
#   'molecules_with_motif': 9966},
#  'NC=O': {'frequency': 0.6713,
#   'total_matches': 9933,
#   'avg_matches_per_mol': 1.4796663190823776,
#   'molecules_with_motif': 6713},
#  'CC(C)N': {'frequency': 0.4278,
#   'total_matches': 6117,
#   'avg_matches_per_mol': 1.4298737727910238,
#   'molecules_with_motif': 4278},
#  'CC(F)F': {'frequency': 0.0367,
#   'total_matches': 1092,
#   'avg_matches_per_mol': 2.975476839237057,
#   'molecules_with_motif': 367},
#  'Oc1ccccc1': {'frequency': 0.2448,
#   'total_matches': 3326,
#   'avg_matches_per_mol': 1.3586601307189543,
#   'molecules_with_motif': 2448},
#  'Cc1ccc(F)cc1': {'frequency': 0.0414,
#   'total_matches': 424,
#   'avg_matches_per_mol': 1.0241545893719808,
#   'molecules_with_motif': 414},
#  'FCF': {'frequency': 0.0442,
#   'total_matches': 1195,
#   'avg_matches_per_mol': 2.7036199095022626,
#   'molecules_with_motif': 442},
#  'CNC': {'frequency': 0.8493,
#   'total_matches': 26437,
#   'avg_matches_per_mol': 3.1127987754621453,
#   'molecules_with_motif': 8493},
#  'CCC': {'frequency': 0.8287,
#   'total_matches': 43174,
#   'avg_matches_per_mol': 5.2098467479184265,
#   'molecules_with_motif': 8287},
#  'CCCCF': {'frequency': 0.0045,
#   'total_matches': 181,
#   'avg_matches_per_mol': 4.022222222222222,
#   'molecules_with_motif': 45},
#  'CCCC': {'frequency': 0.5963,
#   'total_matches': 28506,
#   'avg_matches_per_mol': 4.78047962435016,
#   'molecules_with_motif': 5963},
#  'CCCF': {'frequency': 0.0083,
#   'total_matches': 311,
#   'avg_matches_per_mol': 3.746987951807229,
#   'molecules_with_motif': 83},
#  'C=O': {'frequency': 0.774,
#   'total_matches': 11244,
#   'avg_matches_per_mol': 1.4527131782945737,
#   'molecules_with_motif': 7740},
#  'CCN': {'frequency': 0.9059,
#   'total_matches': 33280,
#   'avg_matches_per_mol': 3.6736946682856826,
#   'molecules_with_motif': 9059},
#  'CC=O': {'frequency': 0.6759,
#   'total_matches': 9563,
#   'avg_matches_per_mol': 1.4148542683828969,
#   'molecules_with_motif': 6759},
#  'O=[N+]([O-])c1ccccc1': {'frequency': 0.0332,
#   'total_matches': 337,
#   'avg_matches_per_mol': 1.0150602409638554,
#   'molecules_with_motif': 332},
#  'Cc1ccccc1O': {'frequency': 0.064,
#   'total_matches': 715,
#   'avg_matches_per_mol': 1.1171875,
#   'molecules_with_motif': 640},
#  'Cc1ccccc1': {'frequency': 0.6126,
#   'total_matches': 9619,
#   'avg_matches_per_mol': 1.570192621612798,
#   'molecules_with_motif': 6126},
#  'FC(F)F': {'frequency': 0.0362,
#   'total_matches': 368,
#   'avg_matches_per_mol': 1.0165745856353592,
#   'molecules_with_motif': 362},
#  'O=Cc1ccccc1': {'frequency': 0.1568,
#   'total_matches': 1724,
#   'avg_matches_per_mol': 1.0994897959183674,
#   'molecules_with_motif': 1568},
#  'CO': {'frequency': 0.5259,
#   'total_matches': 12880,
#   'avg_matches_per_mol': 2.449134816505039,
#   'molecules_with_motif': 5259},
#  'CCc1ccccc1': {'frequency': 0.2784,
#   'total_matches': 4118,
#   'avg_matches_per_mol': 1.4791666666666667,
#   'molecules_with_motif': 2784},
#  'Cc1cccc([N+](=O)[O-])c1': {'frequency': 0.0116,
#   'total_matches': 124,
#   'avg_matches_per_mol': 1.0689655172413792,
#   'molecules_with_motif': 116},
#  'C[NH3+]': {'frequency': 0.2595,
#   'total_matches': 6029,
#   'avg_matches_per_mol': 2.3233140655105973,
#   'molecules_with_motif': 2595},
#  'CCF': {'frequency': 0.038,
#   'total_matches': 1155,
#   'avg_matches_per_mol': 3.039473684210526,
#   'molecules_with_motif': 380},
#  'CCc1ccc(F)cc1': {'frequency': 0.0224,
#   'total_matches': 285,
#   'avg_matches_per_mol': 1.2723214285714286,
#   'molecules_with_motif': 224},
#  'CC(F)(F)F': {'frequency': 0.0346,
#   'total_matches': 352,
#   'avg_matches_per_mol': 1.0173410404624277,
#   'molecules_with_motif': 346},
#  'CCC(F)(F)F': {'frequency': 0.0067,
#   'total_matches': 92,
#   'avg_matches_per_mol': 1.373134328358209,
#   'molecules_with_motif': 67},
#  'CC(N)=O': {'frequency': 0.5866,
#   'total_matches': 7422,
#   'avg_matches_per_mol': 1.2652574156154108,
#   'molecules_with_motif': 5866},
#  'Fc1ccccc1': {'frequency': 0.14,
#   'total_matches': 1739,
#   'avg_matches_per_mol': 1.2421428571428572,
#   'molecules_with_motif': 1400},
#  'O=Cc1cccc([N+](=O)[O-])c1': {'frequency': 0.005,
#   'total_matches': 51,
#   'avg_matches_per_mol': 1.02,
#   'molecules_with_motif': 50},
#  'Cc1cccc(N)c1': {'frequency': 0.0748,
#   'total_matches': 800,
#   'avg_matches_per_mol': 1.0695187165775402,
#   'molecules_with_motif': 748},
#  'O': {'frequency': 0.9344,
#   'total_matches': 23027,
#   'avg_matches_per_mol': 2.4643621575342465,
#   'molecules_with_motif': 9344},
#  'Cc1ccc(C)cc1': {'frequency': 0.0674,
#   'total_matches': 696,
#   'avg_matches_per_mol': 1.032640949554896,
#   'molecules_with_motif': 674},
#  'CN1CCNCC1': {'frequency': 0.0657,
#   'total_matches': 1213,
#   'avg_matches_per_mol': 1.8462709284627092,
#   'molecules_with_motif': 657},
#  'O=CN1CCNCC1': {'frequency': 0.0327,
#   'total_matches': 375,
#   'avg_matches_per_mol': 1.146788990825688,
#   'molecules_with_motif': 327},
#  'C1CC1': {'frequency': 0.0599,
#   'total_matches': 625,
#   'avg_matches_per_mol': 1.0434056761268782,
#   'molecules_with_motif': 599},
#  'C1CNCCN1': {'frequency': 0.066,
#   'total_matches': 674,
#   'avg_matches_per_mol': 1.0212121212121212,
#   'molecules_with_motif': 660},
#  'Cc1ncno1': {'frequency': 0.0194,
#   'total_matches': 196,
#   'avg_matches_per_mol': 1.0103092783505154,
#   'molecules_with_motif': 194},
#  'c1ncon1': {'frequency': 0.0212,
#   'total_matches': 214,
#   'avg_matches_per_mol': 1.009433962264151,
#   'molecules_with_motif': 212},
#  'CC(C)C': {'frequency': 0.3956,
#   'total_matches': 7583,
#   'avg_matches_per_mol': 1.916835187057634,
#   'molecules_with_motif': 3956},
#  'CC1CC1': {'frequency': 0.0434,
#   'total_matches': 632,
#   'avg_matches_per_mol': 1.456221198156682,
#   'molecules_with_motif': 434},
#  'C[C@@H]1CC1': {'frequency': 0.0434,
#   'total_matches': 632,
#   'avg_matches_per_mol': 1.456221198156682,
#   'molecules_with_motif': 434},
#  'C[C@H]1CC1': {'frequency': 0.0434,
#   'total_matches': 632,
#   'avg_matches_per_mol': 1.456221198156682,
#   'molecules_with_motif': 434},
#  'Cc1ncon1': {'frequency': 0.0212,
#   'total_matches': 214,
#   'avg_matches_per_mol': 1.009433962264151,
#   'molecules_with_motif': 212},
#  'Cc1cccnc1': {'frequency': 0.051,
#   'total_matches': 555,
#   'avg_matches_per_mol': 1.088235294117647,
#   'molecules_with_motif': 510},
#  'Cc1cscn1': {'frequency': 0.0342,
#   'total_matches': 345,
#   'avg_matches_per_mol': 1.0087719298245614,
#   'molecules_with_motif': 342},
#  'Cc1nccs1': {'frequency': 0.0331,
#   'total_matches': 332,
#   'avg_matches_per_mol': 1.0030211480362539,
#   'molecules_with_motif': 331},
#  'Cc1csc(C)n1': {'frequency': 0.0183,
#   'total_matches': 184,
#   'avg_matches_per_mol': 1.005464480874317,
#   'molecules_with_motif': 183},
#  'Nc1ccccn1': {'frequency': 0.0255,
#   'total_matches': 257,
#   'avg_matches_per_mol': 1.007843137254902,
#   'molecules_with_motif': 255},
#  'c1cscn1': {'frequency': 0.0677,
#   'total_matches': 692,
#   'avg_matches_per_mol': 1.0221565731166913,
#   'molecules_with_motif': 677},
#  'c1ccncc1': {'frequency': 0.1413,
#   'total_matches': 1484,
#   'avg_matches_per_mol': 1.0502476999292285,
#   'molecules_with_motif': 1413},
#  'CC(C)=O': {'frequency': 0.043,
#   'total_matches': 453,
#   'avg_matches_per_mol': 1.0534883720930233,
#   'molecules_with_motif': 430},
#  'Cc1ccc(Cl)cc1': {'frequency': 0.0322,
#   'total_matches': 325,
#   'avg_matches_per_mol': 1.0093167701863355,
#   'molecules_with_motif': 322},
#  'NS(=O)(=O)c1ccccc1': {'frequency': 0.0451,
#   'total_matches': 458,
#   'avg_matches_per_mol': 1.0155210643015522,
#   'molecules_with_motif': 451},
#  'c1cncnc1': {'frequency': 0.0701,
#   'total_matches': 711,
#   'avg_matches_per_mol': 1.014265335235378,
#   'molecules_with_motif': 701},
#  'O=[SH](=O)c1ccccc1': {'frequency': 0.0552,
#   'total_matches': 568,
#   'avg_matches_per_mol': 1.0289855072463767,
#   'molecules_with_motif': 552},
#  'Cc1ccncn1': {'frequency': 0.0229,
#   'total_matches': 267,
#   'avg_matches_per_mol': 1.165938864628821,
#   'molecules_with_motif': 229},
#  'C=CCC': {'frequency': 0.0447,
#   'total_matches': 1000,
#   'avg_matches_per_mol': 2.237136465324385,
#   'molecules_with_motif': 447},
#  'Cc1ccc(Cl)c(Cl)c1': {'frequency': 0.0023,
#   'total_matches': 25,
#   'avg_matches_per_mol': 1.0869565217391304,
#   'molecules_with_motif': 23},
#  'Cc1cccc(Cl)c1': {'frequency': 0.0238,
#   'total_matches': 246,
#   'avg_matches_per_mol': 1.0336134453781514,
#   'molecules_with_motif': 238},
#  'C[SH](=O)=O': {'frequency': 0.1054,
#   'total_matches': 1418,
#   'avg_matches_per_mol': 1.3453510436432639,
#   'molecules_with_motif': 1054},
#  'N/C=C/C=O': {'frequency': 0.0102,
#   'total_matches': 117,
#   'avg_matches_per_mol': 1.1470588235294117,
#   'molecules_with_motif': 102},
#  'Cc1cc(C)ncn1': {'frequency': 0.0037,
#   'total_matches': 37,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 37},
#  'O=Cc1cccc(Cl)c1': {'frequency': 0.0046,
#   'total_matches': 49,
#   'avg_matches_per_mol': 1.065217391304348,
#   'molecules_with_motif': 46},
#  'Nc1ncccn1': {'frequency': 0.0127,
#   'total_matches': 127,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 127},
#  'Clc1ccccc1Cl': {'frequency': 0.0056,
#   'total_matches': 56,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 56},
#  'CCCO': {'frequency': 0.2319,
#   'total_matches': 4972,
#   'avg_matches_per_mol': 2.1440275981026304,
#   'molecules_with_motif': 2319},
#  'O=c1cc[nH]c2ccccc12': {'frequency': 0.0018,
#   'total_matches': 19,
#   'avg_matches_per_mol': 1.0555555555555556,
#   'molecules_with_motif': 18},
#  'CCO': {'frequency': 0.4106,
#   'total_matches': 9097,
#   'avg_matches_per_mol': 2.2155382367267413,
#   'molecules_with_motif': 4106},
#  'Cn1ccc(=O)c2ccccc21': {'frequency': 0.0012,
#   'total_matches': 13,
#   'avg_matches_per_mol': 1.0833333333333333,
#   'molecules_with_motif': 12},
#  'Cc1ncccn1': {'frequency': 0.0156,
#   'total_matches': 156,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 156},
#  'O=c1cc[nH]cn1': {'frequency': 0.0292,
#   'total_matches': 293,
#   'avg_matches_per_mol': 1.0034246575342465,
#   'molecules_with_motif': 292},
#  'Cn1cnccc1=O': {'frequency': 0.015,
#   'total_matches': 150,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 150},
#  'O=c1ccnc[nH]1': {'frequency': 0.0292,
#   'total_matches': 293,
#   'avg_matches_per_mol': 1.0034246575342465,
#   'molecules_with_motif': 292},
#  'Cc1nccc(=O)[nH]1': {'frequency': 0.0063,
#   'total_matches': 63,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 63},
#  'c1ccc2ncccc2c1': {'frequency': 0.0183,
#   'total_matches': 184,
#   'avg_matches_per_mol': 1.005464480874317,
#   'molecules_with_motif': 183},
#  'O=c1cc[nH]cc1': {'frequency': 0.0024,
#   'total_matches': 24,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 24},
#  'CCC#N': {'frequency': 0.024,
#   'total_matches': 374,
#   'avg_matches_per_mol': 1.5583333333333333,
#   'molecules_with_motif': 240},
#  'c1cn[nH]c1': {'frequency': 0.0917,
#   'total_matches': 940,
#   'avg_matches_per_mol': 1.025081788440567,
#   'molecules_with_motif': 917},
#  'C=C(C)C=O': {'frequency': 0.0211,
#   'total_matches': 237,
#   'avg_matches_per_mol': 1.1232227488151658,
#   'molecules_with_motif': 211},
#  'Cn1cccn1': {'frequency': 0.0742,
#   'total_matches': 761,
#   'avg_matches_per_mol': 1.0256064690026954,
#   'molecules_with_motif': 742},
#  'N#CCC=O': {'frequency': 0.0071,
#   'total_matches': 71,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 71},
#  'CCC=O': {'frequency': 0.3356,
#   'total_matches': 5769,
#   'avg_matches_per_mol': 1.719010727056019,
#   'molecules_with_motif': 3356},
#  'C=C(C)C': {'frequency': 0.0392,
#   'total_matches': 453,
#   'avg_matches_per_mol': 1.155612244897959,
#   'molecules_with_motif': 392},
#  'CCC(N)=O': {'frequency': 0.2699,
#   'total_matches': 4259,
#   'avg_matches_per_mol': 1.577991848832901,
#   'molecules_with_motif': 2699},
#  'CC#N': {'frequency': 0.0552,
#   'total_matches': 587,
#   'avg_matches_per_mol': 1.0634057971014492,
#   'molecules_with_motif': 552},
#  'CC(C)CO': {'frequency': 0.0799,
#   'total_matches': 1252,
#   'avg_matches_per_mol': 1.5669586983729662,
#   'molecules_with_motif': 799},
#  'Cc1cccc(F)c1': {'frequency': 0.0388,
#   'total_matches': 428,
#   'avg_matches_per_mol': 1.1030927835051547,
#   'molecules_with_motif': 388},
#  'C/C([O-])=N/S(C)(=O)=O': {'frequency': 0.0017,
#   'total_matches': 17,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 17},
#  'CC/C([O-])=N/S(=O)(=O)c1ccccc1[N+](=O)[O-]': {'frequency': 0.0001,
#   'total_matches': 2,
#   'avg_matches_per_mol': 2.0,
#   'molecules_with_motif': 1},
#  'CC[O-]': {'frequency': 0.0439,
#   'total_matches': 446,
#   'avg_matches_per_mol': 1.0159453302961277,
#   'molecules_with_motif': 439},
#  'CBr': {'frequency': 0.0477,
#   'total_matches': 492,
#   'avg_matches_per_mol': 1.0314465408805031,
#   'molecules_with_motif': 477},
#  'Brc1ccccc1': {'frequency': 0.0347,
#   'total_matches': 357,
#   'avg_matches_per_mol': 1.0288184438040346,
#   'molecules_with_motif': 347},
#  'Oc1ccccc1Br': {'frequency': 0.0035,
#   'total_matches': 38,
#   'avg_matches_per_mol': 1.0857142857142856,
#   'molecules_with_motif': 35},
#  'CNS(=O)(=O)O': {'frequency': 0.0001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'CCCCC': {'frequency': 0.4202,
#   'total_matches': 18009,
#   'avg_matches_per_mol': 4.285816277962875,
#   'molecules_with_motif': 4202},
#  'c1ccc2[nH]cnc2c1': {'frequency': 0.0176,
#   'total_matches': 176,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 176},
#  'CN1CCCCC1': {'frequency': 0.12,
#   'total_matches': 1277,
#   'avg_matches_per_mol': 1.0641666666666667,
#   'molecules_with_motif': 1200},
#  'CCCCC=O': {'frequency': 0.1082,
#   'total_matches': 2118,
#   'avg_matches_per_mol': 1.9574861367837337,
#   'molecules_with_motif': 1082},
#  'c1ccoc1': {'frequency': 0.0504,
#   'total_matches': 515,
#   'avg_matches_per_mol': 1.0218253968253967,
#   'molecules_with_motif': 504},
#  'Cc1ccco1': {'frequency': 0.0453,
#   'total_matches': 601,
#   'avg_matches_per_mol': 1.3267108167770418,
#   'molecules_with_motif': 453},
#  'CCC(C)C': {'frequency': 0.3212,
#   'total_matches': 11363,
#   'avg_matches_per_mol': 3.537671232876712,
#   'molecules_with_motif': 3212},
#  'Cc1nc2ccccc2n1C': {'frequency': 0.0067,
#   'total_matches': 67,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 67},
#  'CCCC=O': {'frequency': 0.2189,
#   'total_matches': 4297,
#   'avg_matches_per_mol': 1.9629968021927822,
#   'molecules_with_motif': 2189},
#  'CC[C@H](C)C=O': {'frequency': 0.1031,
#   'total_matches': 2392,
#   'avg_matches_per_mol': 2.3200775945683803,
#   'molecules_with_motif': 1031},
#  'CC(C)CC=O': {'frequency': 0.0596,
#   'total_matches': 1016,
#   'avg_matches_per_mol': 1.7046979865771812,
#   'molecules_with_motif': 596},
#  'Cn1cnc2ccccc21': {'frequency': 0.0117,
#   'total_matches': 124,
#   'avg_matches_per_mol': 1.0598290598290598,
#   'molecules_with_motif': 117},
#  'CC[C@@H](C)C=O': {'frequency': 0.1031,
#   'total_matches': 2392,
#   'avg_matches_per_mol': 2.3200775945683803,
#   'molecules_with_motif': 1031},
#  'c1c[nH]cn1': {'frequency': 0.0572,
#   'total_matches': 590,
#   'avg_matches_per_mol': 1.0314685314685315,
#   'molecules_with_motif': 572},
#  'C1CCCNC1': {'frequency': 0.1381,
#   'total_matches': 1462,
#   'avg_matches_per_mol': 1.0586531498913831,
#   'molecules_with_motif': 1381},
#  'C1CCNCC1': {'frequency': 0.1381,
#   'total_matches': 1462,
#   'avg_matches_per_mol': 1.0586531498913831,
#   'molecules_with_motif': 1381},
#  'Cn1ccnc1': {'frequency': 0.0368,
#   'total_matches': 380,
#   'avg_matches_per_mol': 1.0326086956521738,
#   'molecules_with_motif': 368},
#  'CCC(C)CN': {'frequency': 0.1969,
#   'total_matches': 4854,
#   'avg_matches_per_mol': 2.4652107668867447,
#   'molecules_with_motif': 1969},
#  'CC(C)C=O': {'frequency': 0.1262,
#   'total_matches': 1774,
#   'avg_matches_per_mol': 1.4057052297939778,
#   'molecules_with_motif': 1262},
#  'NCC=O': {'frequency': 0.1601,
#   'total_matches': 1860,
#   'avg_matches_per_mol': 1.1617738913179263,
#   'molecules_with_motif': 1601},
#  'CC(C)O': {'frequency': 0.1702,
#   'total_matches': 2703,
#   'avg_matches_per_mol': 1.5881316098707403,
#   'molecules_with_motif': 1702},
#  '[NH3+]CCO': {'frequency': 0.0278,
#   'total_matches': 306,
#   'avg_matches_per_mol': 1.1007194244604317,
#   'molecules_with_motif': 278},
#  'Cc1cc(C)n(C)n1': {'frequency': 0.0142,
#   'total_matches': 143,
#   'avg_matches_per_mol': 1.0070422535211268,
#   'molecules_with_motif': 142},
#  'CCC[NH3+]': {'frequency': 0.1826,
#   'total_matches': 4462,
#   'avg_matches_per_mol': 2.443592552026287,
#   'molecules_with_motif': 1826},
#  'CC[NH3+]': {'frequency': 0.2213,
#   'total_matches': 6548,
#   'avg_matches_per_mol': 2.9588793492995933,
#   'molecules_with_motif': 2213},
#  'Cc1ccn(C)n1': {'frequency': 0.0358,
#   'total_matches': 361,
#   'avg_matches_per_mol': 1.0083798882681565,
#   'molecules_with_motif': 358},
#  'Cc1ccnn1C': {'frequency': 0.0227,
#   'total_matches': 228,
#   'avg_matches_per_mol': 1.0044052863436124,
#   'molecules_with_motif': 227},
#  'Cn1cc(Br)cn1': {'frequency': 0.0007,
#   'total_matches': 7,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 7},
#  'Cc1cc[nH]n1': {'frequency': 0.058,
#   'total_matches': 779,
#   'avg_matches_per_mol': 1.3431034482758621,
#   'molecules_with_motif': 580},
#  'Cc1ccn[nH]1': {'frequency': 0.058,
#   'total_matches': 779,
#   'avg_matches_per_mol': 1.3431034482758621,
#   'molecules_with_motif': 580},
#  'Cc1cc(C)[nH]n1': {'frequency': 0.0191,
#   'total_matches': 192,
#   'avg_matches_per_mol': 1.0052356020942408,
#   'molecules_with_motif': 191},
#  'Cc1cc(=O)c2ccc(O)cc2o1': {'frequency': 0.0004,
#   'total_matches': 4,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 4},
#  'O=c1ccocc1': {'frequency': 0.0027,
#   'total_matches': 27,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 27},
#  'O=c1ccoc2ccccc12': {'frequency': 0.0025,
#   'total_matches': 25,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 25},
#  'Nc1nccs1': {'frequency': 0.023,
#   'total_matches': 232,
#   'avg_matches_per_mol': 1.008695652173913,
#   'molecules_with_motif': 230},
#  'O=c1ccoc2cc(O)ccc12': {'frequency': 0.0007,
#   'total_matches': 7,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 7},
#  'O=c1ccocc1O': {'frequency': 0.0004,
#   'total_matches': 4,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 4},
#  'Cc1ccc(O)cc1': {'frequency': 0.0912,
#   'total_matches': 959,
#   'avg_matches_per_mol': 1.0515350877192982,
#   'molecules_with_motif': 912},
#  'CCCCCC': {'frequency': 0.2017,
#   'total_matches': 8523,
#   'avg_matches_per_mol': 4.225582548339117,
#   'molecules_with_motif': 2017},
#  'CCCC(C)C': {'frequency': 0.1868,
#   'total_matches': 7067,
#   'avg_matches_per_mol': 3.7831905781584583,
#   'molecules_with_motif': 1868},
#  'CC[C@H](C)CC': {'frequency': 0.1821,
#   'total_matches': 6416,
#   'avg_matches_per_mol': 3.5233388248215265,
#   'molecules_with_motif': 1821},
#  'CC[C@H](C)CC=O': {'frequency': 0.0304,
#   'total_matches': 936,
#   'avg_matches_per_mol': 3.0789473684210527,
#   'molecules_with_motif': 304},
#  'CCC[C@H](C)CC': {'frequency': 0.11,
#   'total_matches': 6579,
#   'avg_matches_per_mol': 5.9809090909090905,
#   'molecules_with_motif': 1100},
#  'CCCCCCC': {'frequency': 0.1024,
#   'total_matches': 5128,
#   'avg_matches_per_mol': 5.0078125,
#   'molecules_with_motif': 1024},
#  'CC(C)CCO': {'frequency': 0.0475,
#   'total_matches': 875,
#   'avg_matches_per_mol': 1.8421052631578947,
#   'molecules_with_motif': 475},
#  'O=CCCCC=O': {'frequency': 0.0088,
#   'total_matches': 96,
#   'avg_matches_per_mol': 1.0909090909090908,
#   'molecules_with_motif': 88},
#  'C=C(C)CC': {'frequency': 0.0246,
#   'total_matches': 511,
#   'avg_matches_per_mol': 2.0772357723577235,
#   'molecules_with_motif': 246},
#  'C=CCCCC': {'frequency': 0.0187,
#   'total_matches': 535,
#   'avg_matches_per_mol': 2.8609625668449197,
#   'molecules_with_motif': 187},
#  'CC1=C(C=O)CC2=C(CCCC2=O)N1': {'frequency': 0.0003,
#   'total_matches': 3,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 3},
#  'CCCCCCCC': {'frequency': 0.0485,
#   'total_matches': 2695,
#   'avg_matches_per_mol': 5.556701030927835,
#   'molecules_with_motif': 485},
#  'C=CC[C@H](C)CC': {'frequency': 0.0115,
#   'total_matches': 379,
#   'avg_matches_per_mol': 3.2956521739130435,
#   'molecules_with_motif': 115},
#  'CCCCC(C)C': {'frequency': 0.0919,
#   'total_matches': 3482,
#   'avg_matches_per_mol': 3.7889009793253536,
#   'molecules_with_motif': 919},
#  'CCCCCO': {'frequency': 0.1059,
#   'total_matches': 2264,
#   'avg_matches_per_mol': 2.137865911237016,
#   'molecules_with_motif': 1059},
#  'C=CCCCCC': {'frequency': 0.0081,
#   'total_matches': 240,
#   'avg_matches_per_mol': 2.962962962962963,
#   'molecules_with_motif': 81},
#  'CCC1=CCCCC1': {'frequency': 0.0047,
#   'total_matches': 75,
#   'avg_matches_per_mol': 1.5957446808510638,
#   'molecules_with_motif': 47},
#  'CC[C@@H](C)CC=O': {'frequency': 0.0304,
#   'total_matches': 936,
#   'avg_matches_per_mol': 3.0789473684210527,
#   'molecules_with_motif': 304},
#  'C[C@@H]1CC=CCC1': {'frequency': 0.0081,
#   'total_matches': 148,
#   'avg_matches_per_mol': 1.8271604938271604,
#   'molecules_with_motif': 81},
#  'CCC(C)=O': {'frequency': 0.0263,
#   'total_matches': 522,
#   'avg_matches_per_mol': 1.984790874524715,
#   'molecules_with_motif': 263},
#  'C1=CCCCC1': {'frequency': 0.0111,
#   'total_matches': 119,
#   'avg_matches_per_mol': 1.072072072072072,
#   'molecules_with_motif': 111},
#  'CC[C@H](C)CCO': {'frequency': 0.0328,
#   'total_matches': 900,
#   'avg_matches_per_mol': 2.7439024390243905,
#   'molecules_with_motif': 328},
#  'O=CCCCCO': {'frequency': 0.0107,
#   'total_matches': 124,
#   'avg_matches_per_mol': 1.158878504672897,
#   'molecules_with_motif': 107},
#  'CCC(C)CCO': {'frequency': 0.0328,
#   'total_matches': 900,
#   'avg_matches_per_mol': 2.7439024390243905,
#   'molecules_with_motif': 328},
#  'CCC(C)CC': {'frequency': 0.1821,
#   'total_matches': 6416,
#   'avg_matches_per_mol': 3.5233388248215265,
#   'molecules_with_motif': 1821},
#  'CCC[C@H](C)CC=O': {'frequency': 0.018,
#   'total_matches': 572,
#   'avg_matches_per_mol': 3.1777777777777776,
#   'molecules_with_motif': 180},
#  'C=CCCC': {'frequency': 0.0255,
#   'total_matches': 766,
#   'avg_matches_per_mol': 3.003921568627451,
#   'molecules_with_motif': 255},
#  'CCCCCC=O': {'frequency': 0.0489,
#   'total_matches': 1146,
#   'avg_matches_per_mol': 2.3435582822085887,
#   'molecules_with_motif': 489},
#  'CCCCO': {'frequency': 0.1627,
#   'total_matches': 3553,
#   'avg_matches_per_mol': 2.1837738168408114,
#   'molecules_with_motif': 1627},
#  'C=CCCC=O': {'frequency': 0.0099,
#   'total_matches': 142,
#   'avg_matches_per_mol': 1.4343434343434343,
#   'molecules_with_motif': 99},
#  'C[C@H]1CC=CCC1': {'frequency': 0.0081,
#   'total_matches': 148,
#   'avg_matches_per_mol': 1.8271604938271604,
#   'molecules_with_motif': 81},
#  'CCC[C@@H](C)CC': {'frequency': 0.11,
#   'total_matches': 6579,
#   'avg_matches_per_mol': 5.9809090909090905,
#   'molecules_with_motif': 1100},
#  'CC[C@@H](C)C(=O)[O-]': {'frequency': 0.0105,
#   'total_matches': 275,
#   'avg_matches_per_mol': 2.619047619047619,
#   'molecules_with_motif': 105},
#  'CC(C)[C@@H](C)C(=O)[O-]': {'frequency': 0.004,
#   'total_matches': 75,
#   'avg_matches_per_mol': 1.875,
#   'molecules_with_motif': 40},
#  'Cc1cccs1': {'frequency': 0.0528,
#   'total_matches': 602,
#   'avg_matches_per_mol': 1.1401515151515151,
#   'molecules_with_motif': 528},
#  'CC[C@H](C)CO': {'frequency': 0.0676,
#   'total_matches': 1716,
#   'avg_matches_per_mol': 2.5384615384615383,
#   'molecules_with_motif': 676},
#  'CC[C@H](C)CC(N)=O': {'frequency': 0.0202,
#   'total_matches': 535,
#   'avg_matches_per_mol': 2.6485148514851486,
#   'molecules_with_motif': 202},
#  'O=CCCC=O': {'frequency': 0.0258,
#   'total_matches': 273,
#   'avg_matches_per_mol': 1.058139534883721,
#   'molecules_with_motif': 258},
#  'CC(C)[C@@H](C)CC=O': {'frequency': 0.0094,
#   'total_matches': 239,
#   'avg_matches_per_mol': 2.5425531914893615,
#   'molecules_with_motif': 94},
#  'c1ccsc1': {'frequency': 0.0666,
#   'total_matches': 681,
#   'avg_matches_per_mol': 1.0225225225225225,
#   'molecules_with_motif': 666},
#  'Cc1csc(C)c1C': {'frequency': 0.0042,
#   'total_matches': 42,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 42},
#  'C[C@@H]1CCC[C@H](C)C1': {'frequency': 0.0117,
#   'total_matches': 497,
#   'avg_matches_per_mol': 4.247863247863248,
#   'molecules_with_motif': 117},
#  'CC(C=O)C(C)C': {'frequency': 0.0186,
#   'total_matches': 432,
#   'avg_matches_per_mol': 2.3225806451612905,
#   'molecules_with_motif': 186},
#  'CC1CCCCC1': {'frequency': 0.0484,
#   'total_matches': 1106,
#   'avg_matches_per_mol': 2.2851239669421486,
#   'molecules_with_motif': 484},
#  'C[C@H]1CCCC[C@@H]1C': {'frequency': 0.0092,
#   'total_matches': 222,
#   'avg_matches_per_mol': 2.4130434782608696,
#   'molecules_with_motif': 92},
#  'C1CC2CCC1CC2': {'frequency': 0.0003,
#   'total_matches': 3,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 3},
#  'NC(=O)CCC=O': {'frequency': 0.0243,
#   'total_matches': 380,
#   'avg_matches_per_mol': 1.5637860082304527,
#   'molecules_with_motif': 243},
#  'CC(CC(C)C)C(N)=O': {'frequency': 0.0056,
#   'total_matches': 151,
#   'avg_matches_per_mol': 2.6964285714285716,
#   'molecules_with_motif': 56},
#  'C[C@@H]1CCC[C@@H](C)C1': {'frequency': 0.0117,
#   'total_matches': 497,
#   'avg_matches_per_mol': 4.247863247863248,
#   'molecules_with_motif': 117},
#  'CCCC(C)CO': {'frequency': 0.0383,
#   'total_matches': 979,
#   'avg_matches_per_mol': 2.5561357702349867,
#   'molecules_with_motif': 383},
#  'CCC(=O)[O-]': {'frequency': 0.0237,
#   'total_matches': 378,
#   'avg_matches_per_mol': 1.5949367088607596,
#   'molecules_with_motif': 237},
#  'O=CCCCO': {'frequency': 0.0217,
#   'total_matches': 257,
#   'avg_matches_per_mol': 1.1843317972350231,
#   'molecules_with_motif': 217},
#  'CCC(C)CO': {'frequency': 0.0676,
#   'total_matches': 1716,
#   'avg_matches_per_mol': 2.5384615384615383,
#   'molecules_with_motif': 676},
#  'C[C@@H]1CCCC[C@H]1C': {'frequency': 0.0092,
#   'total_matches': 222,
#   'avg_matches_per_mol': 2.4130434782608696,
#   'molecules_with_motif': 92},
#  'CCC(CC)C(=O)[O-]': {'frequency': 0.0067,
#   'total_matches': 129,
#   'avg_matches_per_mol': 1.9253731343283582,
#   'molecules_with_motif': 67},
#  'C[C@H]1CCCCC1': {'frequency': 0.0484,
#   'total_matches': 1106,
#   'avg_matches_per_mol': 2.2851239669421486,
#   'molecules_with_motif': 484},
#  'CC(C)C[C@H](C)C(=O)[O-]': {'frequency': 0.0016,
#   'total_matches': 28,
#   'avg_matches_per_mol': 1.75,
#   'molecules_with_motif': 16},
#  'CCCC(C)C(=O)[O-]': {'frequency': 0.0072,
#   'total_matches': 160,
#   'avg_matches_per_mol': 2.2222222222222223,
#   'molecules_with_motif': 72},
#  'CCC(C)C(=O)[O-]': {'frequency': 0.0105,
#   'total_matches': 275,
#   'avg_matches_per_mol': 2.619047619047619,
#   'molecules_with_motif': 105},
#  'Cc1ccsc1': {'frequency': 0.0272,
#   'total_matches': 326,
#   'avg_matches_per_mol': 1.1985294117647058,
#   'molecules_with_motif': 272},
#  'CCCC(=O)[O-]': {'frequency': 0.0191,
#   'total_matches': 343,
#   'avg_matches_per_mol': 1.7958115183246073,
#   'molecules_with_motif': 191},
#  'CCC(CC)CC': {'frequency': 0.0539,
#   'total_matches': 1205,
#   'avg_matches_per_mol': 2.235621521335807,
#   'molecules_with_motif': 539},
#  'CCC(C=O)CC': {'frequency': 0.0512,
#   'total_matches': 976,
#   'avg_matches_per_mol': 1.90625,
#   'molecules_with_motif': 512},
#  'C1CCCCC1': {'frequency': 0.0672,
#   'total_matches': 748,
#   'avg_matches_per_mol': 1.1130952380952381,
#   'molecules_with_motif': 672},
#  'CC(C)C(=O)[O-]': {'frequency': 0.0117,
#   'total_matches': 159,
#   'avg_matches_per_mol': 1.358974358974359,
#   'molecules_with_motif': 117},
#  'Cc1ccsc1C': {'frequency': 0.0169,
#   'total_matches': 170,
#   'avg_matches_per_mol': 1.0059171597633136,
#   'molecules_with_motif': 169},
#  'CC(CC=O)C(=O)[O-]': {'frequency': 0.0026,
#   'total_matches': 33,
#   'avg_matches_per_mol': 1.2692307692307692,
#   'molecules_with_motif': 26},
#  'C[C@@H]1CCCC[C@@H]1C': {'frequency': 0.0092,
#   'total_matches': 222,
#   'avg_matches_per_mol': 2.4130434782608696,
#   'molecules_with_motif': 92},
#  'O=CCCC(=O)[O-]': {'frequency': 0.0042,
#   'total_matches': 44,
#   'avg_matches_per_mol': 1.0476190476190477,
#   'molecules_with_motif': 42},
#  'Cc1csc(N)c1': {'frequency': 0.0042,
#   'total_matches': 42,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 42},
#  'O=C[O-]': {'frequency': 0.0385,
#   'total_matches': 391,
#   'avg_matches_per_mol': 1.0155844155844156,
#   'molecules_with_motif': 385},
#  'CC(C)CC(C)C': {'frequency': 0.0332,
#   'total_matches': 917,
#   'avg_matches_per_mol': 2.7620481927710845,
#   'molecules_with_motif': 332},
#  'CC(C)CCCO': {'frequency': 0.0205,
#   'total_matches': 400,
#   'avg_matches_per_mol': 1.951219512195122,
#   'molecules_with_motif': 205},
#  'CC(C)CCC=O': {'frequency': 0.0206,
#   'total_matches': 357,
#   'avg_matches_per_mol': 1.733009708737864,
#   'molecules_with_motif': 206},
#  'C[C@H]1CCC[C@H](C)C1': {'frequency': 0.0117,
#   'total_matches': 497,
#   'avg_matches_per_mol': 4.247863247863248,
#   'molecules_with_motif': 117},
#  'CC[C@@H](C)CC(N)=O': {'frequency': 0.0202,
#   'total_matches': 535,
#   'avg_matches_per_mol': 2.6485148514851486,
#   'molecules_with_motif': 202},
#  'CC(=O)[O-]': {'frequency': 0.0385,
#   'total_matches': 391,
#   'avg_matches_per_mol': 1.0155844155844156,
#   'molecules_with_motif': 385},
#  'C[C@@H]1CCCCC1': {'frequency': 0.0484,
#   'total_matches': 1106,
#   'avg_matches_per_mol': 2.2851239669421486,
#   'molecules_with_motif': 484},
#  'CC(C)CC(=O)[O-]': {'frequency': 0.006,
#   'total_matches': 93,
#   'avg_matches_per_mol': 1.55,
#   'molecules_with_motif': 60},
#  'CCCCC(=O)[O-]': {'frequency': 0.0117,
#   'total_matches': 209,
#   'avg_matches_per_mol': 1.7863247863247864,
#   'molecules_with_motif': 117},
#  'CCCC[C@H](CC)CCO': {'frequency': 0.006,
#   'total_matches': 284,
#   'avg_matches_per_mol': 4.733333333333333,
#   'molecules_with_motif': 60},
#  'Cc1cccc(C)c1': {'frequency': 0.0665,
#   'total_matches': 803,
#   'avg_matches_per_mol': 1.2075187969924812,
#   'molecules_with_motif': 665},
#  'Cc1cc(C)c2oc3c(c(=O)c2c1)[C@@H](c1ccccc1)NC3=O': {'frequency': 0.0001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'CC(C)(C)CC(N)=O': {'frequency': 0.004,
#   'total_matches': 50,
#   'avg_matches_per_mol': 1.25,
#   'molecules_with_motif': 40},
#  'CC1CCNCC1': {'frequency': 0.0412,
#   'total_matches': 458,
#   'avg_matches_per_mol': 1.1116504854368932,
#   'molecules_with_motif': 412},
#  'CC(C)(C)CC=O': {'frequency': 0.0076,
#   'total_matches': 101,
#   'avg_matches_per_mol': 1.3289473684210527,
#   'molecules_with_motif': 76},
#  'C1CC2(CCN1)CC2': {'frequency': 0.0001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'C[C@H]1CCNCC1': {'frequency': 0.0412,
#   'total_matches': 458,
#   'avg_matches_per_mol': 1.1116504854368932,
#   'molecules_with_motif': 412},
#  'O=CC1=CCCC1': {'frequency': 0.0002,
#   'total_matches': 2,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 2},
#  'CCC(C)(C)C': {'frequency': 0.047,
#   'total_matches': 1260,
#   'avg_matches_per_mol': 2.6808510638297873,
#   'molecules_with_motif': 470},
#  'CC(C)(C)C': {'frequency': 0.063,
#   'total_matches': 693,
#   'avg_matches_per_mol': 1.1,
#   'molecules_with_motif': 630},
#  'CCC(C)(CC)CC': {'frequency': 0.0122,
#   'total_matches': 305,
#   'avg_matches_per_mol': 2.5,
#   'molecules_with_motif': 122},
#  'CC1(C)CC1': {'frequency': 0.0057,
#   'total_matches': 69,
#   'avg_matches_per_mol': 1.2105263157894737,
#   'molecules_with_motif': 57},
#  'C1=CCCC1': {'frequency': 0.0053,
#   'total_matches': 53,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 53},
#  'CCC1CC1': {'frequency': 0.0135,
#   'total_matches': 182,
#   'avg_matches_per_mol': 1.348148148148148,
#   'molecules_with_motif': 135},
#  'NCO': {'frequency': 0.0184,
#   'total_matches': 187,
#   'avg_matches_per_mol': 1.016304347826087,
#   'molecules_with_motif': 184},
#  'CCS(N)(=O)=O': {'frequency': 0.0088,
#   'total_matches': 102,
#   'avg_matches_per_mol': 1.1590909090909092,
#   'molecules_with_motif': 88},
#  'CC[SH](=O)=O': {'frequency': 0.0355,
#   'total_matches': 611,
#   'avg_matches_per_mol': 1.7211267605633802,
#   'molecules_with_motif': 355},
#  'c1cc[nH]c1': {'frequency': 0.0399,
#   'total_matches': 400,
#   'avg_matches_per_mol': 1.0025062656641603,
#   'molecules_with_motif': 399},
#  'Cc1cc2ccccc2[nH]1': {'frequency': 0.0076,
#   'total_matches': 76,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 76},
#  'c1ccc2[nH]ccc2c1': {'frequency': 0.0179,
#   'total_matches': 179,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 179},
#  'O=C1Cc2ccccc2N1': {'frequency': 0.0053,
#   'total_matches': 53,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 53},
#  'Cc1ccccc1N': {'frequency': 0.0807,
#   'total_matches': 920,
#   'avg_matches_per_mol': 1.1400247831474597,
#   'molecules_with_motif': 807},
#  'C/C=N\\NC(C)=O': {'frequency': 0.0099,
#   'total_matches': 141,
#   'avg_matches_per_mol': 1.4242424242424243,
#   'molecules_with_motif': 99},
#  'O=CN/N=C/c1ccccc1': {'frequency': 0.0066,
#   'total_matches': 68,
#   'avg_matches_per_mol': 1.0303030303030303,
#   'molecules_with_motif': 66},
#  'O=CN/N=C\\c1ccccc1': {'frequency': 0.0066,
#   'total_matches': 68,
#   'avg_matches_per_mol': 1.0303030303030303,
#   'molecules_with_motif': 66},
#  'CC(=O)NN': {'frequency': 0.0252,
#   'total_matches': 315,
#   'avg_matches_per_mol': 1.25,
#   'molecules_with_motif': 252},
#  'C/C(=N\\NC=O)c1ccccc1': {'frequency': 0.0026,
#   'total_matches': 27,
#   'avg_matches_per_mol': 1.0384615384615385,
#   'molecules_with_motif': 26},
#  'c1ccc2c(c1)CCN2': {'frequency': 0.0119,
#   'total_matches': 119,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 119},
#  'NNC=O': {'frequency': 0.0269,
#   'total_matches': 361,
#   'avg_matches_per_mol': 1.342007434944238,
#   'molecules_with_motif': 269},
#  'Cc1ccc2c(c1)CCN2': {'frequency': 0.0018,
#   'total_matches': 18,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 18},
#  'CC(=O)N/N=C/c1ccccc1': {'frequency': 0.0062,
#   'total_matches': 64,
#   'avg_matches_per_mol': 1.032258064516129,
#   'molecules_with_motif': 62},
#  'CN/N=C/c1ccccc1': {'frequency': 0.009,
#   'total_matches': 116,
#   'avg_matches_per_mol': 1.288888888888889,
#   'molecules_with_motif': 90},
#  'CN1C(=O)Cc2ccccc21': {'frequency': 0.0026,
#   'total_matches': 26,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 26},
#  'Cc1ccc2c(c1)/C(=N/NC=O)C(=O)N2C': {'frequency': 0.0001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'Cc1coc(C)n1': {'frequency': 0.0032,
#   'total_matches': 32,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 32},
#  'Cc1ncco1': {'frequency': 0.0083,
#   'total_matches': 83,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 83},
#  'CC[S@@](C)=O': {'frequency': 0.0344,
#   'total_matches': 1197,
#   'avg_matches_per_mol': 3.479651162790698,
#   'molecules_with_motif': 344},
#  'Cc1ccc([N+](=O)[O-])cc1': {'frequency': 0.0069,
#   'total_matches': 70,
#   'avg_matches_per_mol': 1.0144927536231885,
#   'molecules_with_motif': 69},
#  'CS(C)=O': {'frequency': 0.043,
#   'total_matches': 773,
#   'avg_matches_per_mol': 1.7976744186046512,
#   'molecules_with_motif': 430},
#  'Cc1cocn1': {'frequency': 0.0057,
#   'total_matches': 57,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 57},
#  'c1cocn1': {'frequency': 0.0152,
#   'total_matches': 152,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 152},
#  'CC[S@](C)=O': {'frequency': 0.0344,
#   'total_matches': 1197,
#   'avg_matches_per_mol': 3.479651162790698,
#   'molecules_with_motif': 344},
#  'CC(C)C[NH3+]': {'frequency': 0.061,
#   'total_matches': 936,
#   'avg_matches_per_mol': 1.5344262295081967,
#   'molecules_with_motif': 610},
#  'C[C@@H](C[NH3+])CO': {'frequency': 0.009,
#   'total_matches': 115,
#   'avg_matches_per_mol': 1.2777777777777777,
#   'molecules_with_motif': 90},
#  'CCCC[NH3+]': {'frequency': 0.1402,
#   'total_matches': 3279,
#   'avg_matches_per_mol': 2.3388017118402282,
#   'molecules_with_motif': 1402},
#  'CCCCC[NH3+]': {'frequency': 0.1061,
#   'total_matches': 1998,
#   'avg_matches_per_mol': 1.883129123468426,
#   'molecules_with_motif': 1061},
#  'C[C@@H]1CCOC1': {'frequency': 0.0119,
#   'total_matches': 143,
#   'avg_matches_per_mol': 1.2016806722689075,
#   'molecules_with_motif': 119},
#  'CCC[C@H](C)O': {'frequency': 0.0766,
#   'total_matches': 1810,
#   'avg_matches_per_mol': 2.362924281984334,
#   'molecules_with_motif': 766},
#  'C1CCOC1': {'frequency': 0.0343,
#   'total_matches': 353,
#   'avg_matches_per_mol': 1.0291545189504374,
#   'molecules_with_motif': 343},
#  'CC(C)[NH3+]': {'frequency': 0.1232,
#   'total_matches': 1724,
#   'avg_matches_per_mol': 1.3993506493506493,
#   'molecules_with_motif': 1232},
#  'C1CNC1': {'frequency': 0.0039,
#   'total_matches': 39,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 39},
#  'C1CCC1': {'frequency': 0.0113,
#   'total_matches': 116,
#   'avg_matches_per_mol': 1.0265486725663717,
#   'molecules_with_motif': 113},
#  'C[C@@H]1CCC1': {'frequency': 0.0098,
#   'total_matches': 179,
#   'avg_matches_per_mol': 1.8265306122448979,
#   'molecules_with_motif': 98},
#  'CCC(C)[NH3+]': {'frequency': 0.0958,
#   'total_matches': 2128,
#   'avg_matches_per_mol': 2.221294363256785,
#   'molecules_with_motif': 958},
#  'CCC(C)[C@H](C)[NH3+]': {'frequency': 0.0167,
#   'total_matches': 368,
#   'avg_matches_per_mol': 2.2035928143712575,
#   'molecules_with_motif': 167},
#  'CCC(C)[C@@H](C)O': {'frequency': 0.0252,
#   'total_matches': 752,
#   'avg_matches_per_mol': 2.984126984126984,
#   'molecules_with_motif': 252},
#  'CC[C@H](C)[C@@H](C)[NH3+]': {'frequency': 0.0167,
#   'total_matches': 368,
#   'avg_matches_per_mol': 2.2035928143712575,
#   'molecules_with_motif': 167},
#  'CCC[C@H](O)CC': {'frequency': 0.0309,
#   'total_matches': 1034,
#   'avg_matches_per_mol': 3.3462783171521036,
#   'molecules_with_motif': 309},
#  'CC1CCCO1': {'frequency': 0.0267,
#   'total_matches': 352,
#   'avg_matches_per_mol': 1.3183520599250935,
#   'molecules_with_motif': 267},
#  'CC[C@H](C)[NH3+]': {'frequency': 0.0958,
#   'total_matches': 2128,
#   'avg_matches_per_mol': 2.221294363256785,
#   'molecules_with_motif': 958},
#  '[NH3+]C1CCC1': {'frequency': 0.0013,
#   'total_matches': 13,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 13},
#  'C[C@H]1CCCO1': {'frequency': 0.0267,
#   'total_matches': 352,
#   'avg_matches_per_mol': 1.3183520599250935,
#   'molecules_with_motif': 267},
#  'CC[C@@H](C[NH3+])CO': {'frequency': 0.0076,
#   'total_matches': 95,
#   'avg_matches_per_mol': 1.25,
#   'molecules_with_motif': 76},
#  'CC1CCOC1': {'frequency': 0.0119,
#   'total_matches': 143,
#   'avg_matches_per_mol': 1.2016806722689075,
#   'molecules_with_motif': 119},
#  'CCC(C)O': {'frequency': 0.1051,
#   'total_matches': 2671,
#   'avg_matches_per_mol': 2.5413891531874406,
#   'molecules_with_motif': 1051},
#  '[NH3+][C@@H]1C[C@H]2OCC[C@H]12': {'frequency': 0.0002,
#   'total_matches': 2,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 2},
#  'CC[C@H](C)O': {'frequency': 0.1051,
#   'total_matches': 2671,
#   'avg_matches_per_mol': 2.5413891531874406,
#   'molecules_with_motif': 1051},
#  'CC[C@@H](C)O': {'frequency': 0.1051,
#   'total_matches': 2671,
#   'avg_matches_per_mol': 2.5413891531874406,
#   'molecules_with_motif': 1051},
#  'C[C@@H]1CCCO1': {'frequency': 0.0267,
#   'total_matches': 352,
#   'avg_matches_per_mol': 1.3183520599250935,
#   'molecules_with_motif': 267},
#  'NCC[NH3+]': {'frequency': 0.0824,
#   'total_matches': 1112,
#   'avg_matches_per_mol': 1.3495145631067962,
#   'molecules_with_motif': 824},
#  'CC[C@@H](C)[NH3+]': {'frequency': 0.0958,
#   'total_matches': 2128,
#   'avg_matches_per_mol': 2.221294363256785,
#   'molecules_with_motif': 958},
#  'C[C@H](C)[NH3+]': {'frequency': 0.1232,
#   'total_matches': 1724,
#   'avg_matches_per_mol': 1.3993506493506493,
#   'molecules_with_motif': 1232},
#  '[NH3+]CCCO': {'frequency': 0.0216,
#   'total_matches': 281,
#   'avg_matches_per_mol': 1.3009259259259258,
#   'molecules_with_motif': 216},
#  'CC1CCC1': {'frequency': 0.0098,
#   'total_matches': 179,
#   'avg_matches_per_mol': 1.8265306122448979,
#   'molecules_with_motif': 98},
#  'O=c1cc[nH]c(=O)[nH]1': {'frequency': 0.0071,
#   'total_matches': 71,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 71},
#  'Cn1ccc(=O)n(C)c1=O': {'frequency': 0.0047,
#   'total_matches': 47,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 47},
#  'Cc1cncnc1': {'frequency': 0.0136,
#   'total_matches': 137,
#   'avg_matches_per_mol': 1.0073529411764706,
#   'molecules_with_motif': 136},
#  'CN1CCCC1': {'frequency': 0.092,
#   'total_matches': 962,
#   'avg_matches_per_mol': 1.0456521739130435,
#   'molecules_with_motif': 920},
#  'C1CCNC1': {'frequency': 0.0985,
#   'total_matches': 1038,
#   'avg_matches_per_mol': 1.0538071065989847,
#   'molecules_with_motif': 985},
#  'Cc1cn[nH]c1': {'frequency': 0.0402,
#   'total_matches': 406,
#   'avg_matches_per_mol': 1.0099502487562189,
#   'molecules_with_motif': 402},
#  'Fc1ccccc1Cl': {'frequency': 0.0039,
#   'total_matches': 39,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 39},
#  'Cc1cnn(C)c1': {'frequency': 0.032,
#   'total_matches': 323,
#   'avg_matches_per_mol': 1.009375,
#   'molecules_with_motif': 320},
#  'O=CCCO': {'frequency': 0.0188,
#   'total_matches': 203,
#   'avg_matches_per_mol': 1.0797872340425532,
#   'molecules_with_motif': 188},
#  'C[C@@H](O)C=O': {'frequency': 0.0256,
#   'total_matches': 299,
#   'avg_matches_per_mol': 1.16796875,
#   'molecules_with_motif': 256},
#  'Oc1ccccc1O': {'frequency': 0.0475,
#   'total_matches': 520,
#   'avg_matches_per_mol': 1.0947368421052632,
#   'molecules_with_motif': 475},
#  'C[C@@H]1COc2ccccc2O1': {'frequency': 0.0024,
#   'total_matches': 26,
#   'avg_matches_per_mol': 1.0833333333333333,
#   'molecules_with_motif': 24},
#  'Cc1c[nH]cn1': {'frequency': 0.014,
#   'total_matches': 181,
#   'avg_matches_per_mol': 1.292857142857143,
#   'molecules_with_motif': 140},
#  'c1ccc2c(c1)OCCO2': {'frequency': 0.0091,
#   'total_matches': 92,
#   'avg_matches_per_mol': 1.010989010989011,
#   'molecules_with_motif': 91},
#  'Cc1cn2ccsc2n1': {'frequency': 0.0017,
#   'total_matches': 17,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 17},
#  'C[C@H](O)C=O': {'frequency': 0.0256,
#   'total_matches': 299,
#   'avg_matches_per_mol': 1.16796875,
#   'molecules_with_motif': 256},
#  'C[C@@H](O)CO': {'frequency': 0.0184,
#   'total_matches': 285,
#   'avg_matches_per_mol': 1.548913043478261,
#   'molecules_with_motif': 184},
#  'c1cn2ccsc2n1': {'frequency': 0.0025,
#   'total_matches': 25,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 25},
#  'Cc1cnc[nH]1': {'frequency': 0.014,
#   'total_matches': 181,
#   'avg_matches_per_mol': 1.292857142857143,
#   'molecules_with_motif': 140},
#  'O=CCO': {'frequency': 0.0514,
#   'total_matches': 533,
#   'avg_matches_per_mol': 1.0369649805447472,
#   'molecules_with_motif': 514},
#  'C[C@H]1COc2ccccc2O1': {'frequency': 0.0024,
#   'total_matches': 26,
#   'avg_matches_per_mol': 1.0833333333333333,
#   'molecules_with_motif': 24},
#  'NC(=O)CCO': {'frequency': 0.0127,
#   'total_matches': 134,
#   'avg_matches_per_mol': 1.0551181102362204,
#   'molecules_with_motif': 127},
#  'Cc1ccoc1': {'frequency': 0.0114,
#   'total_matches': 126,
#   'avg_matches_per_mol': 1.105263157894737,
#   'molecules_with_motif': 114},
#  'Nc1cccc(Cl)c1': {'frequency': 0.0195,
#   'total_matches': 202,
#   'avg_matches_per_mol': 1.035897435897436,
#   'molecules_with_motif': 195},
#  '[NH3+][C@@H]1CCCC1': {'frequency': 0.011,
#   'total_matches': 116,
#   'avg_matches_per_mol': 1.0545454545454545,
#   'molecules_with_motif': 110},
#  '[NH3+][C@H]1CCCC1': {'frequency': 0.011,
#   'total_matches': 116,
#   'avg_matches_per_mol': 1.0545454545454545,
#   'molecules_with_motif': 110},
#  'C[C@@H]1CCCCN1': {'frequency': 0.0268,
#   'total_matches': 333,
#   'avg_matches_per_mol': 1.242537313432836,
#   'molecules_with_motif': 268},
#  'C1CCCC1': {'frequency': 0.0449,
#   'total_matches': 491,
#   'avg_matches_per_mol': 1.0935412026726057,
#   'molecules_with_motif': 449},
#  'CCCCS': {'frequency': 0.0382,
#   'total_matches': 656,
#   'avg_matches_per_mol': 1.7172774869109948,
#   'molecules_with_motif': 382},
#  'NC1CCCC1': {'frequency': 0.0253,
#   'total_matches': 296,
#   'avg_matches_per_mol': 1.1699604743083003,
#   'molecules_with_motif': 253},
#  'C[C@H]1CCCCN1': {'frequency': 0.0268,
#   'total_matches': 333,
#   'avg_matches_per_mol': 1.242537313432836,
#   'molecules_with_motif': 268},
#  '[NH3+]CC=O': {'frequency': 0.0291,
#   'total_matches': 301,
#   'avg_matches_per_mol': 1.034364261168385,
#   'molecules_with_motif': 291},
#  '[NH3+]C1CCCC1': {'frequency': 0.011,
#   'total_matches': 116,
#   'avg_matches_per_mol': 1.0545454545454545,
#   'molecules_with_motif': 110},
#  'O=CC=O': {'frequency': 0.0162,
#   'total_matches': 162,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 162},
#  'C[C@@H]1CNC[C@@H]1C': {'frequency': 0.0081,
#   'total_matches': 101,
#   'avg_matches_per_mol': 1.2469135802469136,
#   'molecules_with_motif': 81},
#  'O=C1CCC(=O)N1': {'frequency': 0.0057,
#   'total_matches': 57,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 57},
#  'C=C(C)c1ccccc1': {'frequency': 0.0049,
#   'total_matches': 51,
#   'avg_matches_per_mol': 1.0408163265306123,
#   'molecules_with_motif': 49},
#  'C[C@H]1CCNC1': {'frequency': 0.0354,
#   'total_matches': 508,
#   'avg_matches_per_mol': 1.4350282485875707,
#   'molecules_with_motif': 354},
#  'C[C@H]1CNC[C@@H]1C': {'frequency': 0.0081,
#   'total_matches': 101,
#   'avg_matches_per_mol': 1.2469135802469136,
#   'molecules_with_motif': 81},
#  'C[C@@H]1NCC[C@@H]1C': {'frequency': 0.0043,
#   'total_matches': 60,
#   'avg_matches_per_mol': 1.3953488372093024,
#   'molecules_with_motif': 43},
#  'CC1CCCN1': {'frequency': 0.0367,
#   'total_matches': 428,
#   'avg_matches_per_mol': 1.1662125340599454,
#   'molecules_with_motif': 367},
#  'C[C@H]1CCCN1': {'frequency': 0.0367,
#   'total_matches': 428,
#   'avg_matches_per_mol': 1.1662125340599454,
#   'molecules_with_motif': 367},
#  'C[C@@H]1CCCN1': {'frequency': 0.0367,
#   'total_matches': 428,
#   'avg_matches_per_mol': 1.1662125340599454,
#   'molecules_with_motif': 367},
#  'C[C@H]1CC[C@H](C)N1': {'frequency': 0.0038,
#   'total_matches': 42,
#   'avg_matches_per_mol': 1.105263157894737,
#   'molecules_with_motif': 38},
#  'O=C1CCCN1': {'frequency': 0.0278,
#   'total_matches': 338,
#   'avg_matches_per_mol': 1.2158273381294964,
#   'molecules_with_motif': 278},
#  'C[C@@H]1CNC[C@H]1C': {'frequency': 0.0081,
#   'total_matches': 101,
#   'avg_matches_per_mol': 1.2469135802469136,
#   'molecules_with_motif': 81},
#  'C[C@H]1CNC(=O)C1': {'frequency': 0.0144,
#   'total_matches': 181,
#   'avg_matches_per_mol': 1.2569444444444444,
#   'molecules_with_motif': 144},
#  'CC1CC(=O)NC1=O': {'frequency': 0.0038,
#   'total_matches': 74,
#   'avg_matches_per_mol': 1.9473684210526316,
#   'molecules_with_motif': 38},
#  'CN1C(=O)CCC1=O': {'frequency': 0.0051,
#   'total_matches': 51,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 51},
# ...
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 6},
#  'Fc1cccc(Br)c1': {'frequency': 0.0024,
#   'total_matches': 30,
#   'avg_matches_per_mol': 1.25,
#   'molecules_with_motif': 24},
#  'C/C(N)=N/O': {'frequency': 0.002,
#   'total_matches': 20,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 20},
#  'Nc1ccnc(N)n1': {'frequency': 0.0023,
#   'total_matches': 23,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 23},
#  'c1cnc2ncncc2n1': {'frequency': 0.0001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  '[NH3+]CCCC=O': {'frequency': 0.0069,
#   'total_matches': 99,
#   'avg_matches_per_mol': 1.434782608695652,
#   'molecules_with_motif': 69},
#  'Oc1ccccc1Cl': {'frequency': 0.0095,
#   'total_matches': 98,
#   'avg_matches_per_mol': 1.0315789473684212,
#   'molecules_with_motif': 95},
#  'Clc1cccc2c1OCCCO2': {'frequency': 0.0002,
#   'total_matches': 2,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 2},
#  'Cc1ccc(O)c(Cl)c1': {'frequency': 0.0025,
#   'total_matches': 27,
#   'avg_matches_per_mol': 1.08,
#   'molecules_with_motif': 25},
#  'C[C@H](O)C(C)(C)C': {'frequency': 0.0073,
#   'total_matches': 102,
#   'avg_matches_per_mol': 1.3972602739726028,
#   'molecules_with_motif': 73},
#  'C[C@@H](O)C(C)(C)C': {'frequency': 0.0073,
#   'total_matches': 102,
#   'avg_matches_per_mol': 1.3972602739726028,
#   'molecules_with_motif': 73},
#  'CC(O)C(C)(C)C': {'frequency': 0.0073,
#   'total_matches': 102,
#   'avg_matches_per_mol': 1.3972602739726028,
#   'molecules_with_motif': 73},
#  'CC(C)(C)CO': {'frequency': 0.0142,
#   'total_matches': 158,
#   'avg_matches_per_mol': 1.1126760563380282,
#   'molecules_with_motif': 142},
#  'CCC(C)(C)CO': {'frequency': 0.0123,
#   'total_matches': 290,
#   'avg_matches_per_mol': 2.3577235772357725,
#   'molecules_with_motif': 123},
#  'N#CC1CCOCC1': {'frequency': 0.0001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'CC(C)C(C)(C)O': {'frequency': 0.0056,
#   'total_matches': 113,
#   'avg_matches_per_mol': 2.017857142857143,
#   'molecules_with_motif': 56},
#  'CCC(C)(CC)CCO': {'frequency': 0.0021,
#   'total_matches': 61,
#   'avg_matches_per_mol': 2.9047619047619047,
#   'molecules_with_motif': 21},
#  'CC(C#N)C(C)C': {'frequency': 0.0018,
#   'total_matches': 52,
#   'avg_matches_per_mol': 2.888888888888889,
#   'molecules_with_motif': 18},
#  'CS(=O)(=O)O': {'frequency': 0.0016,
#   'total_matches': 16,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 16},
#  'Cn1cc(S(=O)(=O)O)cn1': {'frequency': 0.0001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'O=C1NC(=O)c2ccccc21': {'frequency': 0.0039,
#   'total_matches': 39,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 39},
#  'c1ccc2c(c1)CNC2': {'frequency': 0.0054,
#   'total_matches': 54,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 54},
#  'N#CC1CCCCC1': {'frequency': 0.0021,
#   'total_matches': 21,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 21},
#  'O=C1NCc2ccccc21': {'frequency': 0.0047,
#   'total_matches': 86,
#   'avg_matches_per_mol': 1.8297872340425532,
#   'molecules_with_motif': 47},
#  'CN1C(=O)c2ccccc2C1=O': {'frequency': 0.0037,
#   'total_matches': 37,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 37},
#  'N[C@H]1CCc2cc(Cl)ccc21': {'frequency': 0.0006,
#   'total_matches': 6,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 6},
#  'N[C@@H]1CCc2cc(Cl)ccc21': {'frequency': 0.0006,
#   'total_matches': 6,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 6},
#  'Nc1ncncn1': {'frequency': 0.001,
#   'total_matches': 22,
#   'avg_matches_per_mol': 2.2,
#   'molecules_with_motif': 10},
#  'c1ncncn1': {'frequency': 0.001,
#   'total_matches': 10,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 10},
#  'C1=C[C@H]2c3ccccc3NC[C@H]2C1': {'frequency': 0.001,
#   'total_matches': 10,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 10},
#  'C1=C[C@@H]2c3ccccc3NC[C@H]2C1': {'frequency': 0.001,
#   'total_matches': 10,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 10},
#  'C1=C[C@@H]2c3ccccc3NC[C@@H]2C1': {'frequency': 0.001,
#   'total_matches': 10,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 10},
#  'C[C@@H]1CCc2ccccc2N1': {'frequency': 0.0016,
#   'total_matches': 16,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 16},
#  'C[C@H]1CCc2ccccc2N1': {'frequency': 0.0016,
#   'total_matches': 16,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 16},
#  'C1=C[C@H]2c3ccccc3NC[C@@H]2C1': {'frequency': 0.001,
#   'total_matches': 10,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 10},
#  'C[C@H]1CCNc2ccccc21': {'frequency': 0.0024,
#   'total_matches': 24,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 24},
#  'C[C@@H]1CCNc2ccccc21': {'frequency': 0.0024,
#   'total_matches': 24,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 24},
#  'Cc1cccc2c1NC[C@H]1CC=C[C@H]21': {'frequency': 0.0006,
#   'total_matches': 6,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 6},
#  'c1cc2c(s1)CCNC2': {'frequency': 0.0011,
#   'total_matches': 11,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 11},
#  'CC(C)[C@H](C)CCl': {'frequency': 0.0002,
#   'total_matches': 2,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 2},
#  'CCCCCl': {'frequency': 0.0013,
#   'total_matches': 28,
#   'avg_matches_per_mol': 2.1538461538461537,
#   'molecules_with_motif': 13},
#  'C1C[C@@H]2CCC[C@@H]2C1': {'frequency': 0.0003,
#   'total_matches': 3,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 3},
#  'C1CCCCCCC1': {'frequency': 0.0034,
#   'total_matches': 68,
#   'avg_matches_per_mol': 2.0,
#   'molecules_with_motif': 34},
#  'C1C[C@@H]2[C@@H]3CC[C@@H](C3)[C@H]2C1': {'frequency': 0.0002,
#   'total_matches': 2,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 2},
#  'C[C@H]1CCC[C@@H]1C': {'frequency': 0.0064,
#   'total_matches': 229,
#   'avg_matches_per_mol': 3.578125,
#   'molecules_with_motif': 64},
#  'C1C[NH2+]C1': {'frequency': 0.0009,
#   'total_matches': 9,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 9},
#  'O=C1CCC2=C1CNc1ccc3ccccc3c12': {'frequency': 0.0001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'CC1(C)Cc2ccsc2C(C)(C)[NH2+]1': {'frequency': 0.0001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'c1cc2c(s1)CNCC2': {'frequency': 0.0008,
#   'total_matches': 8,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 8},
#  'Clc1ccc(Cl)cc1': {'frequency': 0.0019,
#   'total_matches': 19,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 19},
#  'CCCC1=c2ccccc2=[NH+]C1': {'frequency': 0.001,
#   'total_matches': 10,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 10},
#  'O=CCCC1=c2ccccc2=[NH+]C1': {'frequency': 0.0008,
#   'total_matches': 8,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 8},
#  'C1CCCCC[NH2+]1': {'frequency': 0.0026,
#   'total_matches': 26,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 26},
#  'C1CCC[NH2+]CC1': {'frequency': 0.0026,
#   'total_matches': 26,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 26},
#  'NC(=S)N1CCCCC1': {'frequency': 0.0001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'Cc1nc2scc(C)n2c1/C=N/NC=O': {'frequency': 0.0001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'Cc1csc2nccn12': {'frequency': 0.0005,
#   'total_matches': 5,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 5},
#  'Cc1nc2sccn2c1/C=N/NC=O': {'frequency': 0.0002,
#   'total_matches': 2,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 2},
#  'CCCS(=O)(=O)CC': {'frequency': 0.0052,
#   'total_matches': 83,
#   'avg_matches_per_mol': 1.5961538461538463,
#   'molecules_with_motif': 52},
#  'CS(=O)(=O)CCCC=O': {'frequency': 0.001,
#   'total_matches': 11,
#   'avg_matches_per_mol': 1.1,
#   'molecules_with_motif': 10},
#  'CC1CCS(=O)(=O)C1': {'frequency': 0.0015,
#   'total_matches': 15,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 15},
#  'CS(=O)(=O)CCCCO': {'frequency': 0.0002,
#   'total_matches': 2,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 2},
#  'C#CCCC': {'frequency': 0.001,
#   'total_matches': 13,
#   'avg_matches_per_mol': 1.3,
#   'molecules_with_motif': 10},
#  'CS(=O)(=O)CCCCCO': {'frequency': 0.0004,
#   'total_matches': 4,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 4},
#  'C#CCCC(=O)[O-]': {'frequency': 0.0001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'C#CCC': {'frequency': 0.0019,
#   'total_matches': 24,
#   'avg_matches_per_mol': 1.263157894736842,
#   'molecules_with_motif': 19},
#  'CCCC[S@@](C)=O': {'frequency': 0.0074,
#   'total_matches': 228,
#   'avg_matches_per_mol': 3.081081081081081,
#   'molecules_with_motif': 74},
#  'C1CCSCC1': {'frequency': 0.0034,
#   'total_matches': 34,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 34},
#  'OC1CCSCC1': {'frequency': 0.0004,
#   'total_matches': 4,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 4},
#  'C1CCC2(CCSCC2)OC1': {'frequency': 0.0003,
#   'total_matches': 3,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 3},
#  'C[C@H]1Cc2ccccc2N1': {'frequency': 0.0019,
#   'total_matches': 19,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 19},
#  'Cc1coc2c1/C(=N/NC=O)CCC2': {'frequency': 0.0002,
#   'total_matches': 2,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 2},
#  'CC(=O)N/N=C1\\CCCc2occ(C)c21': {'frequency': 0.0002,
#   'total_matches': 2,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 2},
#  'C[C@@H]1Cc2ccccc2N1': {'frequency': 0.0019,
#   'total_matches': 19,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 19},
#  'N#CC1=C(N)C(C#N)(C#N)C[C@H]2CCCC=C12': {'frequency': 0.0002,
#   'total_matches': 2,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 2},
#  'C=CCN1C(=O)[C@]2(c3ccccc31)[C@H]1CCCC=C1C(C#N)=C(N)C2(C#N)C#N': {'frequency': 0.0001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'N#CCC#N': {'frequency': 0.001,
#   'total_matches': 10,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 10},
#  'CCN1C(=O)Cc2ccccc21': {'frequency': 0.002,
#   'total_matches': 21,
#   'avg_matches_per_mol': 1.05,
#   'molecules_with_motif': 20},
#  'CC[C@H](C)CC#N': {'frequency': 0.002,
#   'total_matches': 60,
#   'avg_matches_per_mol': 3.0,
#   'molecules_with_motif': 20},
#  'CCN1C(=O)[C@H](C)c2ccccc21': {'frequency': 0.001,
#   'total_matches': 14,
#   'avg_matches_per_mol': 1.4,
#   'molecules_with_motif': 10},
#  'O=[SH](=O)/C=C/c1ccccc1': {'frequency': 0.0008,
#   'total_matches': 8,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 8},
#  'C1C2CC3CC1CC(C2)C3': {'frequency': 0.0017,
#   'total_matches': 17,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 17},
#  'OCC(F)(F)F': {'frequency': 0.0026,
#   'total_matches': 26,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 26},
#  'O=CN1N=C(c2ccccc2)CC1O': {'frequency': 0.0001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'CC(=O)N1CCC(c2ccccc2)=N1': {'frequency': 0.0011,
#   'total_matches': 11,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 11},
#  'O=CN1CCC(c2ccccc2)=N1': {'frequency': 0.0012,
#   'total_matches': 12,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 12},
#  'Oc1ccc(F)cc1': {'frequency': 0.0076,
#   'total_matches': 78,
#   'avg_matches_per_mol': 1.0263157894736843,
#   'molecules_with_motif': 76},
#  'OC1=Nc2ncsc2[C@@H](c2ccc(F)cc2)C1': {'frequency': 0.0001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'C1CNCC[NH2+]C1': {'frequency': 0.0044,
#   'total_matches': 44,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 44},
#  'C[C@H](O)CCC=O': {'frequency': 0.0068,
#   'total_matches': 98,
#   'avg_matches_per_mol': 1.4411764705882353,
#   'molecules_with_motif': 68},
#  'C[NH+]1CCCNCC1': {'frequency': 0.0038,
#   'total_matches': 38,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 38},
#  'C[C@@H](O)CCC=O': {'frequency': 0.0068,
#   'total_matches': 98,
#   'avg_matches_per_mol': 1.4411764705882353,
#   'molecules_with_motif': 68},
#  'Brc1ccco1': {'frequency': 0.0014,
#   'total_matches': 15,
#   'avg_matches_per_mol': 1.0714285714285714,
#   'molecules_with_motif': 14},
#  'Fc1cccnc1': {'frequency': 0.0029,
#   'total_matches': 29,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 29},
#  'Cc1cncc(F)c1': {'frequency': 0.0004,
#   'total_matches': 4,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 4},
#  'C[C@H]([NH3+])CC=O': {'frequency': 0.0053,
#   'total_matches': 57,
#   'avg_matches_per_mol': 1.0754716981132075,
#   'molecules_with_motif': 53},
#  '[NH3+][C@H]1CCNC1': {'frequency': 0.0048,
#   'total_matches': 48,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 48},
#  '[NH3+][C@@H]1CCNC1': {'frequency': 0.0048,
#   'total_matches': 48,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 48},
#  'O=CS': {'frequency': 0.0023,
#   'total_matches': 23,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 23},
#  'O=C1NCCS1': {'frequency': 0.0016,
#   'total_matches': 16,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 16},
#  'C1CSCCS1': {'frequency': 0.0006,
#   'total_matches': 6,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 6},
#  'O=c1ccc2ccccc2o1': {'frequency': 0.0042,
#   'total_matches': 43,
#   'avg_matches_per_mol': 1.0238095238095237,
#   'molecules_with_motif': 42},
#  'Cc1cc(=O)oc2ccccc12': {'frequency': 0.0027,
#   'total_matches': 27,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 27},
#  'CC(C)S(N)(=O)=O': {'frequency': 0.0014,
#   'total_matches': 14,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 14},
#  '[NH3+]C1CCNCC1': {'frequency': 0.0049,
#   'total_matches': 49,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 49},
#  'c1cnn2cnnc2c1': {'frequency': 0.0009,
#   'total_matches': 9,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 9},
#  'Brc1ccccn1': {'frequency': 0.0008,
#   'total_matches': 8,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 8},
#  'Cc1cccc(Br)n1': {'frequency': 0.0005,
#   'total_matches': 5,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 5},
#  'O=Cc1ccccn1': {'frequency': 0.0058,
#   'total_matches': 59,
#   'avg_matches_per_mol': 1.0172413793103448,
#   'molecules_with_motif': 58},
#  'c1ccc2cnccc2c1': {'frequency': 0.0016,
#   'total_matches': 16,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 16},
#  'O=[N+]([O-])c1cccc2ccncc12': {'frequency': 0.0002,
#   'total_matches': 2,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 2},
#  'Cc1c([N+](=O)[O-])cccc1S(=O)(=O)O': {'frequency': 0.0001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'O=S(=O)(O)c1ccccc1': {'frequency': 0.001,
#   'total_matches': 10,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 10},
#  'Cc1c[nH+]c[nH]1': {'frequency': 0.0017,
#   'total_matches': 17,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 17},
#  'Cn1c(=O)c2cccnc2n(C)c1=O': {'frequency': 0.0006,
#   'total_matches': 6,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 6},
#  'Fc1ccc(F)c2c1CCNC2': {'frequency': 0.0002,
#   'total_matches': 2,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 2},
#  'CC1=C(C=O)CNC(=O)N1': {'frequency': 0.0015,
#   'total_matches': 15,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 15},
#  'O[C@H]1CCCCC1': {'frequency': 0.0117,
#   'total_matches': 139,
#   'avg_matches_per_mol': 1.188034188034188,
#   'molecules_with_motif': 117},
#  'O[C@@H]1CCCCC1': {'frequency': 0.0117,
#   'total_matches': 139,
#   'avg_matches_per_mol': 1.188034188034188,
#   'molecules_with_motif': 117},
#  'OC1CCCCC1': {'frequency': 0.0117,
#   'total_matches': 139,
#   'avg_matches_per_mol': 1.188034188034188,
#   'molecules_with_motif': 117},
#  'C/C(=N/NC(=O)CC#N)c1ccc2cc[nH]c2c1': {'frequency': 0.0001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'c1ccc2ocnc2c1': {'frequency': 0.0068,
#   'total_matches': 68,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 68},
#  'Nc1cccc2ocnc12': {'frequency': 0.0002,
#   'total_matches': 2,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 2},
#  ...}

# %%
motif_stats_smaller = {k: v for k, v in motif_stats.items() if v['frequency'] > min_motif_frequency}
print(f"Number of motifs with frequency > {min_motif_frequency}: {len(motif_stats_smaller)}")
motif_stats_smaller = {k: v for k, v in motif_stats_smaller.items() if Chem.MolFromSmiles(k).GetNumAtoms() >= min_motif_size}
print(f"Number of motifs with frequency > {min_motif_frequency} and num atoms >= {min_motif_size}: {len(motif_stats_smaller)}")
motif_stats_smaller
# Out:
# Number of motifs with frequency > 0.1: 66
# Number of motifs with frequency > 0.1 and num atoms >= 2: 62
# {'Clc1ccccc1': {'frequency': 0.116,
#   'total_matches': 1341,
#   'avg_matches_per_mol': 1.1560344827586206,
#   'molecules_with_motif': 1160,
#   'smiles': 'Clc1ccccc1'},
#  'CCl': {'frequency': 0.144,
#   'total_matches': 1682,
#   'avg_matches_per_mol': 1.1680555555555556,
#   'molecules_with_motif': 1440,
#   'smiles': 'CCl'},
#  'CN': {'frequency': 0.9444,
#   'total_matches': 39008,
#   'avg_matches_per_mol': 4.130453197797544,
#   'molecules_with_motif': 9444,
#   'smiles': 'CN'},
#  'Nc1ccccc1': {'frequency': 0.3248,
#   'total_matches': 3951,
#   'avg_matches_per_mol': 1.2164408866995073,
#   'molecules_with_motif': 3248,
#   'smiles': 'Nc1ccccc1'},
#  'CCS': {'frequency': 0.1407,
#   'total_matches': 2459,
#   'avg_matches_per_mol': 1.747690120824449,
#   'molecules_with_motif': 1407,
#   'smiles': 'CCS'},
#  'CS': {'frequency': 0.223,
#   'total_matches': 3948,
#   'avg_matches_per_mol': 1.770403587443946,
#   'molecules_with_motif': 2230,
#   'smiles': 'CS'},
#  'c1ccccc1': {'frequency': 0.77,
#   'total_matches': 10682,
#   'avg_matches_per_mol': 1.3872727272727272,
#   'molecules_with_motif': 7700,
#   'smiles': 'c1ccccc1'},
#  'CC': {'frequency': 0.9966,
#   'total_matches': 65466,
#   'avg_matches_per_mol': 6.568934376881397,
#   'molecules_with_motif': 9966,
#   'smiles': 'CC'},
#  'NC=O': {'frequency': 0.6713,
#   'total_matches': 9933,
#   'avg_matches_per_mol': 1.4796663190823776,
#   'molecules_with_motif': 6713,
#   'smiles': 'NC=O'},
#  'CC(C)N': {'frequency': 0.4278,
#   'total_matches': 6117,
#   'avg_matches_per_mol': 1.4298737727910238,
#   'molecules_with_motif': 4278,
#   'smiles': 'CC(C)N'},
#  'Oc1ccccc1': {'frequency': 0.2448,
#   'total_matches': 3326,
#   'avg_matches_per_mol': 1.3586601307189543,
#   'molecules_with_motif': 2448,
#   'smiles': 'Oc1ccccc1'},
#  'CNC': {'frequency': 0.8493,
#   'total_matches': 26437,
#   'avg_matches_per_mol': 3.1127987754621453,
#   'molecules_with_motif': 8493,
#   'smiles': 'CNC'},
#  'CCC': {'frequency': 0.8287,
#   'total_matches': 43174,
#   'avg_matches_per_mol': 5.2098467479184265,
#   'molecules_with_motif': 8287,
#   'smiles': 'CCC'},
#  'CCCC': {'frequency': 0.5963,
#   'total_matches': 28506,
#   'avg_matches_per_mol': 4.78047962435016,
#   'molecules_with_motif': 5963,
#   'smiles': 'CCCC'},
#  'C=O': {'frequency': 0.774,
#   'total_matches': 11244,
#   'avg_matches_per_mol': 1.4527131782945737,
#   'molecules_with_motif': 7740,
#   'smiles': 'C=O'},
#  'CCN': {'frequency': 0.9059,
#   'total_matches': 33280,
#   'avg_matches_per_mol': 3.6736946682856826,
#   'molecules_with_motif': 9059,
#   'smiles': 'CCN'},
#  'CC=O': {'frequency': 0.6759,
#   'total_matches': 9563,
#   'avg_matches_per_mol': 1.4148542683828969,
#   'molecules_with_motif': 6759,
#   'smiles': 'CC=O'},
#  'Cc1ccccc1': {'frequency': 0.6126,
#   'total_matches': 9619,
#   'avg_matches_per_mol': 1.570192621612798,
#   'molecules_with_motif': 6126,
#   'smiles': 'Cc1ccccc1'},
#  'O=Cc1ccccc1': {'frequency': 0.1568,
#   'total_matches': 1724,
#   'avg_matches_per_mol': 1.0994897959183674,
#   'molecules_with_motif': 1568,
#   'smiles': 'O=Cc1ccccc1'},
#  'CO': {'frequency': 0.5259,
#   'total_matches': 12880,
#   'avg_matches_per_mol': 2.449134816505039,
#   'molecules_with_motif': 5259,
#   'smiles': 'CO'},
#  'CCc1ccccc1': {'frequency': 0.2784,
#   'total_matches': 4118,
#   'avg_matches_per_mol': 1.4791666666666667,
#   'molecules_with_motif': 2784,
#   'smiles': 'CCc1ccccc1'},
#  'C[NH3+]': {'frequency': 0.2595,
#   'total_matches': 6029,
#   'avg_matches_per_mol': 2.3233140655105973,
#   'molecules_with_motif': 2595,
#   'smiles': 'C[NH3+]'},
#  'CC(N)=O': {'frequency': 0.5866,
#   'total_matches': 7422,
#   'avg_matches_per_mol': 1.2652574156154108,
#   'molecules_with_motif': 5866,
#   'smiles': 'CC(N)=O'},
#  'Fc1ccccc1': {'frequency': 0.14,
#   'total_matches': 1739,
#   'avg_matches_per_mol': 1.2421428571428572,
#   'molecules_with_motif': 1400,
#   'smiles': 'Fc1ccccc1'},
#  'CC(C)C': {'frequency': 0.3956,
#   'total_matches': 7583,
#   'avg_matches_per_mol': 1.916835187057634,
#   'molecules_with_motif': 3956,
#   'smiles': 'CC(C)C'},
#  'c1ccncc1': {'frequency': 0.1413,
#   'total_matches': 1484,
#   'avg_matches_per_mol': 1.0502476999292285,
#   'molecules_with_motif': 1413,
#   'smiles': 'c1ccncc1'},
#  'C[SH](=O)=O': {'frequency': 0.1054,
#   'total_matches': 1418,
#   'avg_matches_per_mol': 1.3453510436432639,
#   'molecules_with_motif': 1054,
#   'smiles': 'C[SH](=O)=O'},
#  'CCCO': {'frequency': 0.2319,
#   'total_matches': 4972,
#   'avg_matches_per_mol': 2.1440275981026304,
#   'molecules_with_motif': 2319,
#   'smiles': 'CCCO'},
#  'CCO': {'frequency': 0.4106,
#   'total_matches': 9097,
#   'avg_matches_per_mol': 2.2155382367267413,
#   'molecules_with_motif': 4106,
#   'smiles': 'CCO'},
#  'CCC=O': {'frequency': 0.3356,
#   'total_matches': 5769,
#   'avg_matches_per_mol': 1.719010727056019,
#   'molecules_with_motif': 3356,
#   'smiles': 'CCC=O'},
#  'CCC(N)=O': {'frequency': 0.2699,
#   'total_matches': 4259,
#   'avg_matches_per_mol': 1.577991848832901,
#   'molecules_with_motif': 2699,
#   'smiles': 'CCC(N)=O'},
#  'CCCCC': {'frequency': 0.4202,
#   'total_matches': 18009,
#   'avg_matches_per_mol': 4.285816277962875,
#   'molecules_with_motif': 4202,
#   'smiles': 'CCCCC'},
#  'CN1CCCCC1': {'frequency': 0.12,
#   'total_matches': 1277,
#   'avg_matches_per_mol': 1.0641666666666667,
#   'molecules_with_motif': 1200,
#   'smiles': 'CN1CCCCC1'},
#  'CCCCC=O': {'frequency': 0.1082,
#   'total_matches': 2118,
#   'avg_matches_per_mol': 1.9574861367837337,
#   'molecules_with_motif': 1082,
#   'smiles': 'CCCCC=O'},
#  'CCC(C)C': {'frequency': 0.3212,
#   'total_matches': 11363,
#   'avg_matches_per_mol': 3.537671232876712,
#   'molecules_with_motif': 3212,
#   'smiles': 'CCC(C)C'},
#  'CCCC=O': {'frequency': 0.2189,
#   'total_matches': 4297,
#   'avg_matches_per_mol': 1.9629968021927822,
#   'molecules_with_motif': 2189,
#   'smiles': 'CCCC=O'},
#  'CC[C@H](C)C=O': {'frequency': 0.1031,
#   'total_matches': 2392,
#   'avg_matches_per_mol': 2.3200775945683803,
#   'molecules_with_motif': 1031,
#   'smiles': 'CC[C@H](C)C=O'},
#  'CC[C@@H](C)C=O': {'frequency': 0.1031,
#   'total_matches': 2392,
#   'avg_matches_per_mol': 2.3200775945683803,
#   'molecules_with_motif': 1031,
#   'smiles': 'CC[C@@H](C)C=O'},
#  'C1CCCNC1': {'frequency': 0.1381,
#   'total_matches': 1462,
#   'avg_matches_per_mol': 1.0586531498913831,
#   'molecules_with_motif': 1381,
#   'smiles': 'C1CCCNC1'},
#  'C1CCNCC1': {'frequency': 0.1381,
#   'total_matches': 1462,
#   'avg_matches_per_mol': 1.0586531498913831,
#   'molecules_with_motif': 1381,
#   'smiles': 'C1CCNCC1'},
#  'CCC(C)CN': {'frequency': 0.1969,
#   'total_matches': 4854,
#   'avg_matches_per_mol': 2.4652107668867447,
#   'molecules_with_motif': 1969,
#   'smiles': 'CCC(C)CN'},
#  'CC(C)C=O': {'frequency': 0.1262,
#   'total_matches': 1774,
#   'avg_matches_per_mol': 1.4057052297939778,
#   'molecules_with_motif': 1262,
#   'smiles': 'CC(C)C=O'},
#  'NCC=O': {'frequency': 0.1601,
#   'total_matches': 1860,
#   'avg_matches_per_mol': 1.1617738913179263,
#   'molecules_with_motif': 1601,
#   'smiles': 'NCC=O'},
#  'CC(C)O': {'frequency': 0.1702,
#   'total_matches': 2703,
#   'avg_matches_per_mol': 1.5881316098707403,
#   'molecules_with_motif': 1702,
#   'smiles': 'CC(C)O'},
#  'CCC[NH3+]': {'frequency': 0.1826,
#   'total_matches': 4462,
#   'avg_matches_per_mol': 2.443592552026287,
#   'molecules_with_motif': 1826,
#   'smiles': 'CCC[NH3+]'},
#  'CC[NH3+]': {'frequency': 0.2213,
#   'total_matches': 6548,
#   'avg_matches_per_mol': 2.9588793492995933,
#   'molecules_with_motif': 2213,
#   'smiles': 'CC[NH3+]'},
#  'CCCCCC': {'frequency': 0.2017,
#   'total_matches': 8523,
#   'avg_matches_per_mol': 4.225582548339117,
#   'molecules_with_motif': 2017,
#   'smiles': 'CCCCCC'},
#  'CCCC(C)C': {'frequency': 0.1868,
#   'total_matches': 7067,
#   'avg_matches_per_mol': 3.7831905781584583,
#   'molecules_with_motif': 1868,
#   'smiles': 'CCCC(C)C'},
#  'CC[C@H](C)CC': {'frequency': 0.1821,
#   'total_matches': 6416,
#   'avg_matches_per_mol': 3.5233388248215265,
#   'molecules_with_motif': 1821,
#   'smiles': 'CC[C@H](C)CC'},
#  'CCC[C@H](C)CC': {'frequency': 0.11,
#   'total_matches': 6579,
#   'avg_matches_per_mol': 5.9809090909090905,
#   'molecules_with_motif': 1100,
#   'smiles': 'CCC[C@H](C)CC'},
#  'CCCCCCC': {'frequency': 0.1024,
#   'total_matches': 5128,
#   'avg_matches_per_mol': 5.0078125,
#   'molecules_with_motif': 1024,
#   'smiles': 'CCCCCCC'},
#  'CCCCCO': {'frequency': 0.1059,
#   'total_matches': 2264,
#   'avg_matches_per_mol': 2.137865911237016,
#   'molecules_with_motif': 1059,
#   'smiles': 'CCCCCO'},
#  'CCC(C)CC': {'frequency': 0.1821,
#   'total_matches': 6416,
#   'avg_matches_per_mol': 3.5233388248215265,
#   'molecules_with_motif': 1821,
#   'smiles': 'CCC(C)CC'},
#  'CCCCO': {'frequency': 0.1627,
#   'total_matches': 3553,
#   'avg_matches_per_mol': 2.1837738168408114,
#   'molecules_with_motif': 1627,
#   'smiles': 'CCCCO'},
#  'CCC[C@@H](C)CC': {'frequency': 0.11,
#   'total_matches': 6579,
#   'avg_matches_per_mol': 5.9809090909090905,
#   'molecules_with_motif': 1100,
#   'smiles': 'CCC[C@@H](C)CC'},
#  'CCCC[NH3+]': {'frequency': 0.1402,
#   'total_matches': 3279,
#   'avg_matches_per_mol': 2.3388017118402282,
#   'molecules_with_motif': 1402,
#   'smiles': 'CCCC[NH3+]'},
#  'CCCCC[NH3+]': {'frequency': 0.1061,
#   'total_matches': 1998,
#   'avg_matches_per_mol': 1.883129123468426,
#   'molecules_with_motif': 1061,
#   'smiles': 'CCCCC[NH3+]'},
#  'CC(C)[NH3+]': {'frequency': 0.1232,
#   'total_matches': 1724,
#   'avg_matches_per_mol': 1.3993506493506493,
#   'molecules_with_motif': 1232,
#   'smiles': 'CC(C)[NH3+]'},
#  'CCC(C)O': {'frequency': 0.1051,
#   'total_matches': 2671,
#   'avg_matches_per_mol': 2.5413891531874406,
#   'molecules_with_motif': 1051,
#   'smiles': 'CCC(C)O'},
#  'CC[C@H](C)O': {'frequency': 0.1051,
#   'total_matches': 2671,
#   'avg_matches_per_mol': 2.5413891531874406,
#   'molecules_with_motif': 1051,
#   'smiles': 'CC[C@H](C)O'},
#  'CC[C@@H](C)O': {'frequency': 0.1051,
#   'total_matches': 2671,
#   'avg_matches_per_mol': 2.5413891531874406,
#   'molecules_with_motif': 1051,
#   'smiles': 'CC[C@@H](C)O'},
#  'C[C@H](C)[NH3+]': {'frequency': 0.1232,
#   'total_matches': 1724,
#   'avg_matches_per_mol': 1.3993506493506493,
#   'molecules_with_motif': 1232,
#   'smiles': 'C[C@H](C)[NH3+]'}}

# %%
def visualize_motif_frequency(motif_stats, top_n=20):
    for key in motif_stats.keys():
        motif_stats[key]["smiles"] = key
    
    sorted_motifs = sorted(motif_stats.items(), 
                          key=lambda x: x[1]['frequency'], 
                          reverse=True)[:top_n]
    
    motifs = [item[0] for item in sorted_motifs]
    frequencies = [item[1]['frequency'] * 100 for item in sorted_motifs]
    
    plt.figure(figsize=(15, 10))
    
    # Create subplot for frequency
    plt.subplot(2, 1, 1)
    bars = plt.bar(range(len(motifs)), frequencies, color='skyblue', alpha=0.7)
    plt.ylabel('Frequency (%)')
    plt.title(f'Most Frequent Motifs in ZINC Dataset (dataset size = {num_molecules})')
    plt.xticks(range(len(motifs)), [motif_stats[motif]['smiles'] for motif in motifs], rotation=45)
    
    for i, bar in enumerate(bars):
        height = bar.get_height()
        plt.text(bar.get_x() + bar.get_width()/2., height + 0.5,
                f'{frequencies[i]:.1f}%', ha='center', va='bottom', fontsize=8)
    
    # Create subplot for total matches
    total_matches = [item[1]['total_matches'] for item in sorted_motifs]
    plt.subplot(2, 1, 2)
    bars2 = plt.bar(range(len(motifs)), total_matches, color='lightcoral', alpha=0.7)
    plt.ylabel('Total Matches')
    plt.title(f'Total Matches for Most Frequent Motifs (dataset size = {num_molecules})')
    plt.xticks(range(len(motifs)), [motif_stats[motif]['smiles'] for motif in motifs], rotation=45)
    
    for i, bar in enumerate(bars2):
        height = bar.get_height()
        plt.text(bar.get_x() + bar.get_width()/2., height + 5,
                f'{total_matches[i]}', ha='center', va='bottom', fontsize=8)
    
    plt.tight_layout()
    plt.show()
    
visualize_motif_frequency(motif_stats_smaller, top_n=20)

# %%
num_matches = [motif_stats_smaller[key]["total_matches"] for key in motif_stats_smaller.keys()]
print(f"Total number of matches: {sum(num_matches)}")
# Out:
# Total number of matches: 514466

# %%
list(motif_stats_smaller.keys())
# Out:
# ['Clc1ccccc1',
#  'CCl',
#  'CN',
#  'Nc1ccccc1',
#  'CCS',
#  'CS',
#  'c1ccccc1',
#  'CC',
#  'NC=O',
#  'CC(C)N',
#  'Oc1ccccc1',
#  'CNC',
#  'CCC',
#  'CCCC',
#  'C=O',
#  'CCN',
#  'CC=O',
#  'Cc1ccccc1',
#  'O=Cc1ccccc1',
#  'CO',
#  'CCc1ccccc1',
#  'C[NH3+]',
#  'CC(N)=O',
#  'Fc1ccccc1',
#  'CC(C)C',
#  'c1ccncc1',
#  'C[SH](=O)=O',
#  'CCCO',
#  'CCO',
#  'CCC=O',
#  'CCC(N)=O',
#  'CCCCC',
#  'CN1CCCCC1',
#  'CCCCC=O',
#  'CCC(C)C',
#  'CCCC=O',
#  'CC[C@H](C)C=O',
#  'CC[C@@H](C)C=O',
#  'C1CCCNC1',
#  'C1CCNCC1',
#  'CCC(C)CN',
#  'CC(C)C=O',
#  'NCC=O',
#  'CC(C)O',
#  'CCC[NH3+]',
#  'CC[NH3+]',
#  'CCCCCC',
#  'CCCC(C)C',
#  'CC[C@H](C)CC',
#  'CCC[C@H](C)CC',
#  'CCCCCCC',
#  'CCCCCO',
#  'CCC(C)CC',
#  'CCCCO',
#  'CCC[C@@H](C)CC',
#  'CCCC[NH3+]',
#  'CCCCC[NH3+]',
#  'CC(C)[NH3+]',
#  'CCC(C)O',
#  'CC[C@H](C)O',
#  'CC[C@@H](C)O',
#  'C[C@H](C)[NH3+]']

# %%
# ZINC

manually_cleaned_motifs = [
    'C=O',
    'NC=O',
    'C1=CC=CC=C1',
    'NCCO',
    'OC1=CC=CC=C1',
    'NC1=CC=CC=C1',
    'COC',
    'C1=CC=NC=C1',
    'NCN',
    'O=S',
    'CN1CCCCC1',
    'C1CCNCC1',
    'O=CO']

# %%
manually_cleaned_stats = {k: v for k, v in motif_stats.items() if k in manually_cleaned_motifs}
manually_cleaned_stats
# Out:
# {'NC=O': {'frequency': 0.6713,
#   'total_matches': 9933,
#   'avg_matches_per_mol': 1.4796663190823776,
#   'molecules_with_motif': 6713,
#   'smiles': 'NC=O'},
#  'C=O': {'frequency': 0.774,
#   'total_matches': 11244,
#   'avg_matches_per_mol': 1.4527131782945737,
#   'molecules_with_motif': 7740,
#   'smiles': 'C=O'},
#  'CN1CCCCC1': {'frequency': 0.12,
#   'total_matches': 1277,
#   'avg_matches_per_mol': 1.0641666666666667,
#   'molecules_with_motif': 1200,
#   'smiles': 'CN1CCCCC1'},
#  'C1CCNCC1': {'frequency': 0.1381,
#   'total_matches': 1462,
#   'avg_matches_per_mol': 1.0586531498913831,
#   'molecules_with_motif': 1381,
#   'smiles': 'C1CCNCC1'}}

# %%
num_matches = [manually_cleaned_stats[key]["total_matches"] for key in manually_cleaned_stats.keys()]
print(f"Total number of matches: {sum(num_matches)}")
# Out:
# Total number of matches: 5735

# %%
visualize_motif_frequency(manually_cleaned_stats, top_n=20)

# %%
num_matches = [manually_cleaned_stats[key]["total_matches"] for key in manually_cleaned_stats.keys()]
print(f"Total number of matches: {sum(num_matches)}")
print(f"Total number of motifs: {len(manually_cleaned_stats)}")
# Out:
# Total number of matches: 2469
# Total number of motifs: 10

# %%
def plot_motif_dualbars(
    motif_stats,
    num_molecules,
    top_n=20,
):
    fig_width_in=6.0
    height_per_bar_in=0.32
    outfile="motifs_dualbars.pdf"
    palette=("#0072B2", "#D55E00")

    figure_height = max(1.6, height_per_bar_in * max(3, top_n) + 0.6)
    with mpl.rc_context({
        "figure.figsize": (fig_width_in, figure_height),
        "figure.dpi": 150,
        "savefig.dpi": 600,
        "savefig.bbox": "tight",
        "savefig.pad_inches": 0.02,
        "font.size": 11,
        "axes.titlesize": 11,
        "axes.labelsize": 11,
        "legend.fontsize": 11,
        "xtick.labelsize": 11,
        "ytick.labelsize": 11,
        "font.family": "serif",
        "axes.linewidth": 0.8,
        "grid.linewidth": 0.4,
        "grid.alpha": 0.25,
        "grid.linestyle": "--",
        "legend.frameon": False,
        "pdf.fonttype": 42,
        "ps.fonttype": 42,
    }):
        rows = []
        for k, v in motif_stats.items():
            f = float(v["frequency"])
            pct = 100.0 * f
            n = v["total_matches"]
            rows.append((k, pct, n))

        rows.sort(key=lambda t: t[2], reverse=True)
        rows = rows[:top_n]

        motifs = [r[0] for r in rows][::-1]
        freq_pct = np.array([r[1] for r in rows], dtype=float)[::-1]
        counts = np.array([r[2] for r in rows], dtype=int)[::-1]

        y_labels = motifs

        freq_color, count_color = palette
        fig, ax_pct = plt.subplots()

        y = np.arange(len(motifs))
        bar_h = 0.42  # group height ~0.84

        b1 = ax_pct.barh(
            y - bar_h/2, freq_pct, height=bar_h, label="Frequency (%)",
            color=freq_color, alpha=0.9, edgecolor="none", zorder=3
        )
        ax_pct.set_xlabel("Frequency (%)")
        ax_pct.set_yticks(y)
        ax_pct.set_yticklabels(y_labels)
        ax_pct.invert_yaxis()
        ax_pct.xaxis.set_major_locator(MaxNLocator(5))
        ax_pct.xaxis.set_major_formatter(PercentFormatter(xmax=100, decimals=0))
        ax_pct.grid(axis="x", zorder=0)

        ax_cnt = ax_pct.twiny()
        b2 = ax_cnt.barh(
            y + bar_h/2, counts, height=bar_h, label="Total matches (n)",
            color=count_color, alpha=0.9, edgecolor="none", zorder=2
        )
        ax_cnt.set_xlabel("Total matches (n)")
        ax_cnt.xaxis.set_major_locator(MaxNLocator(5, integer=True))
        ax_cnt.xaxis.set_major_formatter(FuncFormatter(lambda x, pos: f"{int(x):,}"))

        legend_handles = [
            Patch(facecolor=freq_color, edgecolor="none", label="Frequency (%)"),
            Patch(facecolor=count_color, edgecolor="none", label="Total matches (n)"),
        ]
        ax_pct.legend(handles=legend_handles, loc="upper right")

        # ax_pct.set_title(f"The {len(motifs)} most frequent motifs in first {num_molecules:,} molecules of PCQM4Mv2")

        for spine in ["top", "right"]:
            ax_pct.spines[spine].set_visible(False)
        ax_cnt.spines["bottom"].set_visible(False)  # avoid double baseline

        fig.tight_layout()
        fig.savefig(outfile)
        return fig, (ax_pct, ax_cnt)

fig, ax = plot_motif_dualbars(manually_cleaned_stats, num_molecules=num_molecules, top_n=20)
