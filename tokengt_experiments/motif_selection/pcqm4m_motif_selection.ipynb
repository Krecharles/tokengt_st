# %%
import pandas as pd
import numpy as np
from rdkit import Chem
from rdkit.Chem import AllChem
from collections import defaultdict
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm import tqdm
import warnings
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter, MaxNLocator, PercentFormatter
from matplotlib.patches import Patch

warnings.filterwarnings('ignore')

# Suppress RDKit warnings
import rdkit
lg = rdkit.RDLogger.logger()
lg.setLevel(rdkit.RDLogger.CRITICAL)

# %%
def load_molecules(file_path, num_molecules=None):
    molecules = []
    smiles_list = []
    
    print(f"Loading first {num_molecules} molecules from {file_path}...")
    
    with open(file_path, 'r') as f:
        for i, line in enumerate(f):
            if num_molecules is not None and i >= num_molecules:
                break
            
            smiles = line.strip()
            mol = Chem.MolFromSmiles(smiles)
            
            if mol is not None:
                molecules.append(mol)
                smiles_list.append(smiles)
    
    print(f"Successfully loaded {len(molecules)} valid molecules")
    return molecules, smiles_list

def find_motif_matches(molecules, motif_mols, motif_smiles):
    results = defaultdict(list)

    for mol_idx, mol in enumerate(tqdm(molecules, desc="Processing molecules")):
        for motif_idx, motif_mol in enumerate(motif_mols):
            matches = mol.GetSubstructMatches(motif_mol)
            
            if matches:
                results[motif_smiles[motif_idx]].append({
                    'molecule_idx': mol_idx,
                    'num_matches': len(matches),
                    'match_positions': matches
                })
    
    return results


def analyze_motif_frequency(match_results, num_molecules):
    motif_stats = {}
    
    for motif_smiles, matches in match_results.items():
        molecules_with_motif = len(set(match['molecule_idx'] for match in matches))
        total_matches = sum(match['num_matches'] for match in matches)
        motif_stats[motif_smiles] = {
            'frequency': molecules_with_motif / num_molecules,
            'total_matches': total_matches,
            'avg_matches_per_mol': total_matches / molecules_with_motif if molecules_with_motif > 0 else 0,
            'molecules_with_motif': molecules_with_motif
        }
    
    return motif_stats

# %%
from torch_geometric.datasets import PCQM4Mv2

motif_file = "tokengt_experiments/motif_selection/clique.txt"
num_molecules = 1000
min_motif_size = 2
min_motif_frequency = 0.1

motifs, motif_smiles = load_molecules(motif_file)

dataset = PCQM4Mv2(root='data/pcqm4m', split='train')
mol_smiles = [dataset[i].smiles for i in range(num_molecules)]
molecules = [Chem.MolFromSmiles(smiles) for smiles in mol_smiles]
# Out:
# Loading first None molecules from tokengt_experiments/motif_selection/clique.txt...
# Successfully loaded 12233 valid molecules

# %%
match_results = find_motif_matches(molecules, motifs, motif_smiles)
motif_stats = analyze_motif_frequency(match_results, len(molecules))
motif_stats
# Out:
# Processing molecules: 100%|██████████| 1000/1000 [01:01<00:00, 16.33it/s]
# {'CC': {'frequency': 0.975,
#   'total_matches': 5386,
#   'avg_matches_per_mol': 5.524102564102564,
#   'molecules_with_motif': 975},
#  'CN': {'frequency': 0.704,
#   'total_matches': 1811,
#   'avg_matches_per_mol': 2.5724431818181817,
#   'molecules_with_motif': 704},
#  'CCN': {'frequency': 0.617,
#   'total_matches': 1659,
#   'avg_matches_per_mol': 2.6888168557536467,
#   'molecules_with_motif': 617},
#  'CN1C=CN=C1': {'frequency': 0.02,
#   'total_matches': 21,
#   'avg_matches_per_mol': 1.05,
#   'molecules_with_motif': 20},
#  'CC1=CN=C[NH]1': {'frequency': 0.017,
#   'total_matches': 19,
#   'avg_matches_per_mol': 1.1176470588235294,
#   'molecules_with_motif': 17},
#  'CC1=C[NH]C=N1': {'frequency': 0.017,
#   'total_matches': 19,
#   'avg_matches_per_mol': 1.1176470588235294,
#   'molecules_with_motif': 17},
#  'CCCCC': {'frequency': 0.413,
#   'total_matches': 2212,
#   'avg_matches_per_mol': 5.3559322033898304,
#   'molecules_with_motif': 413},
#  'CCCCCC': {'frequency': 0.256,
#   'total_matches': 1311,
#   'avg_matches_per_mol': 5.12109375,
#   'molecules_with_motif': 256},
#  'N': {'frequency': 0.791,
#   'total_matches': 1658,
#   'avg_matches_per_mol': 2.0960809102402025,
#   'molecules_with_motif': 791},
#  'CCCN': {'frequency': 0.462,
#   'total_matches': 1123,
#   'avg_matches_per_mol': 2.430735930735931,
#   'molecules_with_motif': 462},
#  'C1=C[NH]C=N1': {'frequency': 0.045,
#   'total_matches': 45,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 45},
#  'CCCC': {'frequency': 0.582,
#   'total_matches': 3076,
#   'avg_matches_per_mol': 5.285223367697594,
#   'molecules_with_motif': 582},
#  'CN1CCCCC1': {'frequency': 0.038,
#   'total_matches': 39,
#   'avg_matches_per_mol': 1.0263157894736843,
#   'molecules_with_motif': 38},
#  'C': {'frequency': 0.999,
#   'total_matches': 10549,
#   'avg_matches_per_mol': 10.55955955955956,
#   'molecules_with_motif': 999},
#  'CCC': {'frequency': 0.815,
#   'total_matches': 4284,
#   'avg_matches_per_mol': 5.256441717791411,
#   'molecules_with_motif': 815},
#  'CC1CCCNC1': {'frequency': 0.02,
#   'total_matches': 25,
#   'avg_matches_per_mol': 1.25,
#   'molecules_with_motif': 20},
#  'C1CCNCC1': {'frequency': 0.056,
#   'total_matches': 58,
#   'avg_matches_per_mol': 1.0357142857142858,
#   'molecules_with_motif': 56},
#  'C1CCCCC1': {'frequency': 0.07,
#   'total_matches': 77,
#   'avg_matches_per_mol': 1.1,
#   'molecules_with_motif': 70},
#  'C1CNC1': {'frequency': 0.006,
#   'total_matches': 6,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 6},
#  'NC1CCCCC1': {'frequency': 0.03,
#   'total_matches': 33,
#   'avg_matches_per_mol': 1.1,
#   'molecules_with_motif': 30},
#  'O=CO': {'frequency': 0.181,
#   'total_matches': 207,
#   'avg_matches_per_mol': 1.143646408839779,
#   'molecules_with_motif': 181},
#  'C=O': {'frequency': 0.358,
#   'total_matches': 445,
#   'avg_matches_per_mol': 1.2430167597765363,
#   'molecules_with_motif': 358},
#  'NC=O': {'frequency': 0.112,
#   'total_matches': 127,
#   'avg_matches_per_mol': 1.1339285714285714,
#   'molecules_with_motif': 112},
#  'CCO': {'frequency': 0.528,
#   'total_matches': 1159,
#   'avg_matches_per_mol': 2.195075757575758,
#   'molecules_with_motif': 528},
#  'C1=CC=CC=C1': {'frequency': 0.38,
#   'total_matches': 410,
#   'avg_matches_per_mol': 1.0789473684210527,
#   'molecules_with_motif': 380},
#  'CO': {'frequency': 0.596,
#   'total_matches': 1261,
#   'avg_matches_per_mol': 2.115771812080537,
#   'molecules_with_motif': 596},
#  'CC=O': {'frequency': 0.326,
#   'total_matches': 475,
#   'avg_matches_per_mol': 1.4570552147239264,
#   'molecules_with_motif': 326},
#  'NCCO': {'frequency': 0.147,
#   'total_matches': 180,
#   'avg_matches_per_mol': 1.2244897959183674,
#   'molecules_with_motif': 147},
#  'O': {'frequency': 0.754,
#   'total_matches': 1528,
#   'avg_matches_per_mol': 2.026525198938992,
#   'molecules_with_motif': 754},
#  'CC1=CC=CC=C1': {'frequency': 0.296,
#   'total_matches': 441,
#   'avg_matches_per_mol': 1.489864864864865,
#   'molecules_with_motif': 296},
#  'COC': {'frequency': 0.298,
#   'total_matches': 379,
#   'avg_matches_per_mol': 1.2718120805369129,
#   'molecules_with_motif': 298},
#  'C=N': {'frequency': 0.2,
#   'total_matches': 224,
#   'avg_matches_per_mol': 1.12,
#   'molecules_with_motif': 200},
#  'C1=CC=C2[NH]C=NC2=C1': {'frequency': 0.013,
#   'total_matches': 13,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 13},
#  'COCO': {'frequency': 0.031,
#   'total_matches': 57,
#   'avg_matches_per_mol': 1.8387096774193548,
#   'molecules_with_motif': 31},
#  'C=NC': {'frequency': 0.14,
#   'total_matches': 153,
#   'avg_matches_per_mol': 1.0928571428571427,
#   'molecules_with_motif': 140},
#  'C1=CC2=C(C=C1)[NH]C=N2': {'frequency': 0.013,
#   'total_matches': 13,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 13},
#  'NC1=NC2=CC=CC=C2[NH]1': {'frequency': 0.002,
#   'total_matches': 2,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 2},
#  'N=CO': {'frequency': 0.117,
#   'total_matches': 130,
#   'avg_matches_per_mol': 1.1111111111111112,
#   'molecules_with_motif': 117},
#  'OCO': {'frequency': 0.034,
#   'total_matches': 37,
#   'avg_matches_per_mol': 1.088235294117647,
#   'molecules_with_motif': 34},
#  'CCC#N': {'frequency': 0.026,
#   'total_matches': 40,
#   'avg_matches_per_mol': 1.5384615384615385,
#   'molecules_with_motif': 26},
#  'CC=N': {'frequency': 0.151,
#   'total_matches': 181,
#   'avg_matches_per_mol': 1.1986754966887416,
#   'molecules_with_motif': 151},
#  'CC#N': {'frequency': 0.043,
#   'total_matches': 45,
#   'avg_matches_per_mol': 1.0465116279069768,
#   'molecules_with_motif': 43},
#  'C=NCC': {'frequency': 0.098,
#   'total_matches': 144,
#   'avg_matches_per_mol': 1.469387755102041,
#   'molecules_with_motif': 98},
#  'C#N': {'frequency': 0.044,
#   'total_matches': 46,
#   'avg_matches_per_mol': 1.0454545454545454,
#   'molecules_with_motif': 44},
#  'C=NCCC': {'frequency': 0.065,
#   'total_matches': 95,
#   'avg_matches_per_mol': 1.4615384615384615,
#   'molecules_with_motif': 65},
#  'C=CCC': {'frequency': 0.112,
#   'total_matches': 260,
#   'avg_matches_per_mol': 2.3214285714285716,
#   'molecules_with_motif': 112},
#  'NCO': {'frequency': 0.038,
#   'total_matches': 41,
#   'avg_matches_per_mol': 1.0789473684210527,
#   'molecules_with_motif': 38},
#  'C1=NCC(C2=CC=CC=C2)=C1': {'frequency': 0.001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'C1=CCN=C1': {'frequency': 0.002,
#   'total_matches': 2,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 2},
#  'C=C': {'frequency': 0.175,
#   'total_matches': 227,
#   'avg_matches_per_mol': 1.2971428571428572,
#   'molecules_with_motif': 175},
#  'CCCO': {'frequency': 0.383,
#   'total_matches': 906,
#   'avg_matches_per_mol': 2.3655352480417755,
#   'molecules_with_motif': 383},
#  'C=CC': {'frequency': 0.169,
#   'total_matches': 447,
#   'avg_matches_per_mol': 2.6449704142011834,
#   'molecules_with_motif': 169},
#  'CC1C=CC=N1': {'frequency': 0.001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'C=CCN': {'frequency': 0.042,
#   'total_matches': 49,
#   'avg_matches_per_mol': 1.1666666666666667,
#   'molecules_with_motif': 42},
#  'CCCCO': {'frequency': 0.259,
#   'total_matches': 656,
#   'avg_matches_per_mol': 2.5328185328185326,
#   'molecules_with_motif': 259},
#  'CCCCCO': {'frequency': 0.172,
#   'total_matches': 466,
#   'avg_matches_per_mol': 2.7093023255813953,
#   'molecules_with_motif': 172},
#  'CCC=O': {'frequency': 0.208,
#   'total_matches': 372,
#   'avg_matches_per_mol': 1.7884615384615385,
#   'molecules_with_motif': 208},
#  'CC#CC': {'frequency': 0.006,
#   'total_matches': 8,
#   'avg_matches_per_mol': 1.3333333333333333,
#   'molecules_with_motif': 6},
#  'C#CC': {'frequency': 0.013,
#   'total_matches': 25,
#   'avg_matches_per_mol': 1.9230769230769231,
#   'molecules_with_motif': 13},
#  'CC#CCC': {'frequency': 0.004,
#   'total_matches': 5,
#   'avg_matches_per_mol': 1.25,
#   'molecules_with_motif': 4},
#  'C#CCC': {'frequency': 0.005,
#   'total_matches': 8,
#   'avg_matches_per_mol': 1.6,
#   'molecules_with_motif': 5},
#  'C#CCCC': {'frequency': 0.004,
#   'total_matches': 8,
#   'avg_matches_per_mol': 2.0,
#   'molecules_with_motif': 4},
#  'C#C': {'frequency': 0.014,
#   'total_matches': 21,
#   'avg_matches_per_mol': 1.5,
#   'molecules_with_motif': 14},
#  'C#CCCCC': {'frequency': 0.002,
#   'total_matches': 4,
#   'avg_matches_per_mol': 2.0,
#   'molecules_with_motif': 2},
#  'Cl': {'frequency': 0.082,
#   'total_matches': 98,
#   'avg_matches_per_mol': 1.1951219512195121,
#   'molecules_with_motif': 82},
#  'CCl': {'frequency': 0.081,
#   'total_matches': 94,
#   'avg_matches_per_mol': 1.1604938271604939,
#   'molecules_with_motif': 81},
#  'OCCl': {'frequency': 0.003,
#   'total_matches': 4,
#   'avg_matches_per_mol': 1.3333333333333333,
#   'molecules_with_motif': 3},
#  'C=CCCC': {'frequency': 0.079,
#   'total_matches': 193,
#   'avg_matches_per_mol': 2.4430379746835444,
#   'molecules_with_motif': 79},
#  'C1=CCCCC1': {'frequency': 0.012,
#   'total_matches': 12,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 12},
#  'CN1C=CC=N1': {'frequency': 0.036,
#   'total_matches': 36,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 36},
#  'CC1=N[NH]C=C1': {'frequency': 0.035,
#   'total_matches': 44,
#   'avg_matches_per_mol': 1.2571428571428571,
#   'molecules_with_motif': 35},
#  'C1=CC=NC=C1': {'frequency': 0.07,
#   'total_matches': 74,
#   'avg_matches_per_mol': 1.0571428571428572,
#   'molecules_with_motif': 70},
#  'C1=C[NH]N=C1': {'frequency': 0.052,
#   'total_matches': 53,
#   'avg_matches_per_mol': 1.0192307692307692,
#   'molecules_with_motif': 52},
#  'CC1=NC=CC=C1': {'frequency': 0.016,
#   'total_matches': 17,
#   'avg_matches_per_mol': 1.0625,
#   'molecules_with_motif': 16},
#  'CC1=CC=N[NH]1': {'frequency': 0.035,
#   'total_matches': 44,
#   'avg_matches_per_mol': 1.2571428571428571,
#   'molecules_with_motif': 35},
#  'CC1=CC=CC=N1': {'frequency': 0.016,
#   'total_matches': 17,
#   'avg_matches_per_mol': 1.0625,
#   'molecules_with_motif': 16},
#  'OC1CCCCC1': {'frequency': 0.026,
#   'total_matches': 35,
#   'avg_matches_per_mol': 1.3461538461538463,
#   'molecules_with_motif': 26},
#  'CC1CCCCC1O': {'frequency': 0.015,
#   'total_matches': 31,
#   'avg_matches_per_mol': 2.066666666666667,
#   'molecules_with_motif': 15},
#  'CCCCCCCC': {'frequency': 0.094,
#   'total_matches': 412,
#   'avg_matches_per_mol': 4.382978723404255,
#   'molecules_with_motif': 94},
#  'CC1CCCCC1': {'frequency': 0.061,
#   'total_matches': 123,
#   'avg_matches_per_mol': 2.0163934426229506,
#   'molecules_with_motif': 61},
#  'CC1CCCC(O)C1': {'frequency': 0.011,
#   'total_matches': 25,
#   'avg_matches_per_mol': 2.272727272727273,
#   'molecules_with_motif': 11},
#  'CC1=C[NH]N=C1': {'frequency': 0.015,
#   'total_matches': 15,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 15},
#  'C1=NCCOC1': {'frequency': 0.001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'C=NNC': {'frequency': 0.011,
#   'total_matches': 15,
#   'avg_matches_per_mol': 1.3636363636363635,
#   'molecules_with_motif': 11},
#  'CNN': {'frequency': 0.047,
#   'total_matches': 93,
#   'avg_matches_per_mol': 1.9787234042553192,
#   'molecules_with_motif': 47},
#  'NCN': {'frequency': 0.047,
#   'total_matches': 56,
#   'avg_matches_per_mol': 1.1914893617021276,
#   'molecules_with_motif': 47},
#  'NN': {'frequency': 0.055,
#   'total_matches': 61,
#   'avg_matches_per_mol': 1.1090909090909091,
#   'molecules_with_motif': 55},
#  'C=NN': {'frequency': 0.017,
#   'total_matches': 17,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 17},
#  'CC=NN': {'frequency': 0.016,
#   'total_matches': 20,
#   'avg_matches_per_mol': 1.25,
#   'molecules_with_motif': 16},
#  'OC1=CC=CC=C1': {'frequency': 0.091,
#   'total_matches': 122,
#   'avg_matches_per_mol': 1.3406593406593406,
#   'molecules_with_motif': 91},
#  'CCCl': {'frequency': 0.038,
#   'total_matches': 51,
#   'avg_matches_per_mol': 1.3421052631578947,
#   'molecules_with_motif': 38},
#  'CCCCCl': {'frequency': 0.011,
#   'total_matches': 21,
#   'avg_matches_per_mol': 1.9090909090909092,
#   'molecules_with_motif': 11},
#  'CCCCCCl': {'frequency': 0.006,
#   'total_matches': 15,
#   'avg_matches_per_mol': 2.5,
#   'molecules_with_motif': 6},
#  'CCCCl': {'frequency': 0.018,
#   'total_matches': 32,
#   'avg_matches_per_mol': 1.7777777777777777,
#   'molecules_with_motif': 18},
#  'F': {'frequency': 0.096,
#   'total_matches': 179,
#   'avg_matches_per_mol': 1.8645833333333333,
#   'molecules_with_motif': 96},
#  'CF': {'frequency': 0.096,
#   'total_matches': 179,
#   'avg_matches_per_mol': 1.8645833333333333,
#   'molecules_with_motif': 96},
#  'CC1=CC=C(C2CC2)O1': {'frequency': 0.001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'CC1CC1C': {'frequency': 0.017,
#   'total_matches': 34,
#   'avg_matches_per_mol': 2.0,
#   'molecules_with_motif': 17},
#  'NO': {'frequency': 0.069,
#   'total_matches': 75,
#   'avg_matches_per_mol': 1.0869565217391304,
#   'molecules_with_motif': 69},
#  'CC1CC1': {'frequency': 0.049,
#   'total_matches': 84,
#   'avg_matches_per_mol': 1.7142857142857142,
#   'molecules_with_motif': 49},
#  'CNO': {'frequency': 0.047,
#   'total_matches': 53,
#   'avg_matches_per_mol': 1.127659574468085,
#   'molecules_with_motif': 47},
#  'CCNO': {'frequency': 0.017,
#   'total_matches': 21,
#   'avg_matches_per_mol': 1.2352941176470589,
#   'molecules_with_motif': 17},
#  'C1CC1': {'frequency': 0.067,
#   'total_matches': 70,
#   'avg_matches_per_mol': 1.044776119402985,
#   'molecules_with_motif': 67},
#  'CC1=CC=CO1': {'frequency': 0.027,
#   'total_matches': 37,
#   'avg_matches_per_mol': 1.3703703703703705,
#   'molecules_with_motif': 27},
#  'C1=COC(C2CC2)=C1': {'frequency': 0.001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'C1=COC=C1': {'frequency': 0.036,
#   'total_matches': 37,
#   'avg_matches_per_mol': 1.0277777777777777,
#   'molecules_with_motif': 36},
#  'CN1CCCC1': {'frequency': 0.032,
#   'total_matches': 32,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 32},
#  'CC1CCCN1': {'frequency': 0.027,
#   'total_matches': 36,
#   'avg_matches_per_mol': 1.3333333333333333,
#   'molecules_with_motif': 27},
#  'C1CCNC1': {'frequency': 0.051,
#   'total_matches': 52,
#   'avg_matches_per_mol': 1.0196078431372548,
#   'molecules_with_motif': 51},
#  'OC1CCNC1': {'frequency': 0.007,
#   'total_matches': 9,
#   'avg_matches_per_mol': 1.2857142857142858,
#   'molecules_with_motif': 7},
#  'CC1CCCC1': {'frequency': 0.032,
#   'total_matches': 80,
#   'avg_matches_per_mol': 2.5,
#   'molecules_with_motif': 32},
#  'C1CCCC1': {'frequency': 0.045,
#   'total_matches': 51,
#   'avg_matches_per_mol': 1.1333333333333333,
#   'molecules_with_motif': 45},
#  'C1=CC=C2SC=CC2=C1': {'frequency': 0.001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'CC1=CC2=CC=CC=C2S1': {'frequency': 0.001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'CC1=CC=CS1': {'frequency': 0.019,
#   'total_matches': 23,
#   'avg_matches_per_mol': 1.2105263157894737,
#   'molecules_with_motif': 19},
#  'S': {'frequency': 0.151,
#   'total_matches': 171,
#   'avg_matches_per_mol': 1.1324503311258278,
#   'molecules_with_motif': 151},
#  'C1=CC=C2C=CC=CC2=C1': {'frequency': 0.006,
#   'total_matches': 6,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 6},
#  'C1=CC2=CC=C3C=CSC3=C2C=C1': {'frequency': 0.001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'C1=CSC=C1': {'frequency': 0.022,
#   'total_matches': 24,
#   'avg_matches_per_mol': 1.0909090909090908,
#   'molecules_with_motif': 22},
#  'C1CCOCC1': {'frequency': 0.019,
#   'total_matches': 21,
#   'avg_matches_per_mol': 1.105263157894737,
#   'molecules_with_motif': 19},
#  'CS': {'frequency': 0.106,
#   'total_matches': 205,
#   'avg_matches_per_mol': 1.9339622641509433,
#   'molecules_with_motif': 106},
#  'CCS': {'frequency': 0.08,
#   'total_matches': 140,
#   'avg_matches_per_mol': 1.75,
#   'molecules_with_motif': 80},
#  'CCCS': {'frequency': 0.054,
#   'total_matches': 94,
#   'avg_matches_per_mol': 1.7407407407407407,
#   'molecules_with_motif': 54},
#  'NC1CCCC1': {'frequency': 0.023,
#   'total_matches': 23,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 23},
#  'CC1=COC=C1': {'frequency': 0.013,
#   'total_matches': 13,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 13},
#  'NC1=CC=CC=C1': {'frequency': 0.125,
#   'total_matches': 140,
#   'avg_matches_per_mol': 1.12,
#   'molecules_with_motif': 125},
#  'C1=CC=C(C2CO2)C=C1': {'frequency': 0.001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'C1CO1': {'frequency': 0.008,
#   'total_matches': 8,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 8},
#  'CC1CO1': {'frequency': 0.008,
#   'total_matches': 18,
#   'avg_matches_per_mol': 2.25,
#   'molecules_with_motif': 8},
#  'C1=CC2=C(C=C1)CCCC2': {'frequency': 0.007,
#   'total_matches': 7,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 7},
#  'OC1CCC2=CC=CC=C2C1': {'frequency': 0.003,
#   'total_matches': 4,
#   'avg_matches_per_mol': 1.3333333333333333,
#   'molecules_with_motif': 3},
#  'C1=CC=C2CCCCC2=C1': {'frequency': 0.007,
#   'total_matches': 7,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 7},
#  'OC1CCCC2=CC=CC=C21': {'frequency': 0.001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'OC1CCNCC1': {'frequency': 0.005,
#   'total_matches': 5,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 5},
#  'OC1CCCNC1': {'frequency': 0.001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'NC1=NC=CC=N1': {'frequency': 0.005,
#   'total_matches': 5,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 5},
#  'C1=CN=CN=C1': {'frequency': 0.028,
#   'total_matches': 28,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 28},
#  'CCCCS': {'frequency': 0.033,
#   'total_matches': 54,
#   'avg_matches_per_mol': 1.6363636363636365,
#   'molecules_with_motif': 33},
#  'SC1=NC=CC=C1': {'frequency': 0.004,
#   'total_matches': 4,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 4},
#  'CCCC#N': {'frequency': 0.014,
#   'total_matches': 23,
#   'avg_matches_per_mol': 1.6428571428571428,
#   'molecules_with_motif': 14},
#  'NC1=CC=CN=C1': {'frequency': 0.011,
#   'total_matches': 11,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 11},
#  'SC1=CC=CC=N1': {'frequency': 0.004,
#   'total_matches': 4,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 4},
#  'NC1=CN=CC=C1': {'frequency': 0.011,
#   'total_matches': 11,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 11},
#  'SC1=NC=C[NH]1': {'frequency': 0.003,
#   'total_matches': 3,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 3},
#  'SC1=NC2=CC=CC=C2[NH]1': {'frequency': 0.002,
#   'total_matches': 2,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 2},
#  'C=CCCCCC': {'frequency': 0.041,
#   'total_matches': 99,
#   'avg_matches_per_mol': 2.4146341463414633,
#   'molecules_with_motif': 41},
#  'C1CNCCNC1': {'frequency': 0.001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'CN1CCCNCC1': {'frequency': 0.001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'SC1=NC=NC=C1': {'frequency': 0.001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'SC1=CC=NC=N1': {'frequency': 0.001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'NC1CC1': {'frequency': 0.018,
#   'total_matches': 19,
#   'avg_matches_per_mol': 1.0555555555555556,
#   'molecules_with_motif': 18},
#  'CCF': {'frequency': 0.036,
#   'total_matches': 122,
#   'avg_matches_per_mol': 3.388888888888889,
#   'molecules_with_motif': 36},
#  'CCCC=N': {'frequency': 0.061,
#   'total_matches': 94,
#   'avg_matches_per_mol': 1.540983606557377,
#   'molecules_with_motif': 61},
#  'CC1CCCO1': {'frequency': 0.018,
#   'total_matches': 25,
#   'avg_matches_per_mol': 1.3888888888888888,
#   'molecules_with_motif': 18},
#  'C1CCOC1': {'frequency': 0.029,
#   'total_matches': 30,
#   'avg_matches_per_mol': 1.0344827586206897,
#   'molecules_with_motif': 29},
#  'C1CCCNCC1': {'frequency': 0.005,
#   'total_matches': 5,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 5},
#  'C1CC2CNCC1C2': {'frequency': 0.001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'CON': {'frequency': 0.016,
#   'total_matches': 16,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 16},
#  'CC=CN': {'frequency': 0.028,
#   'total_matches': 54,
#   'avg_matches_per_mol': 1.9285714285714286,
#   'molecules_with_motif': 28},
#  'C=CN': {'frequency': 0.033,
#   'total_matches': 51,
#   'avg_matches_per_mol': 1.5454545454545454,
#   'molecules_with_motif': 33},
#  'C1=CCNC=C1': {'frequency': 0.01,
#   'total_matches': 10,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 10},
#  'ON1C=CC=CC1': {'frequency': 0.001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'C=CNOC': {'frequency': 0.002,
#   'total_matches': 2,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 2},
#  'CC1=CC=NO1': {'frequency': 0.009,
#   'total_matches': 9,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 9},
#  'CC1=NOC=C1': {'frequency': 0.008,
#   'total_matches': 8,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 8},
#  'C1=CON=C1': {'frequency': 0.009,
#   'total_matches': 9,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 9},
#  'CC1=CC=CC=C1C1=CC=CC=C1': {'frequency': 0.003,
#   'total_matches': 4,
#   'avg_matches_per_mol': 1.3333333333333333,
#   'molecules_with_motif': 3},
#  'C1=CC=C(C2=CC=CC=C2)C=C1': {'frequency': 0.007,
#   'total_matches': 7,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 7},
#  'C1=CC=C2C(=C1)CC1=C2C=CC=C1': {'frequency': 0.001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'C1=CC=C2C(=C1)CC1=CC=CC=C12': {'frequency': 0.001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'NC1=CC=C(C2=CC=CC=C2)C=C1': {'frequency': 0.003,
#   'total_matches': 3,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 3},
#  'CC1=NC=NC=C1': {'frequency': 0.008,
#   'total_matches': 8,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 8},
#  'CC1=NC=CC=N1': {'frequency': 0.006,
#   'total_matches': 6,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 6},
#  'CC1=CC=NC=N1': {'frequency': 0.008,
#   'total_matches': 8,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 8},
#  'OC1=CC=NC=N1': {'frequency': 0.007,
#   'total_matches': 7,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 7},
#  'OC1=NC=NC=C1': {'frequency': 0.007,
#   'total_matches': 7,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 7},
#  'C1=CC2=C(N=C1)[NH]C=C2': {'frequency': 0.002,
#   'total_matches': 2,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 2},
#  'C1=C[NH]C=C1': {'frequency': 0.024,
#   'total_matches': 24,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 24},
#  'C1=CCNCC1': {'frequency': 0.003,
#   'total_matches': 3,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 3},
#  'C1=C(C2=C[NH]C3=NC=CC=C23)CCNC1': {'frequency': 0.001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'C1=CN=C2[NH]C=CC2=C1': {'frequency': 0.002,
#   'total_matches': 2,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 2},
#  'CC1=C[NH]C=C1': {'frequency': 0.009,
#   'total_matches': 9,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 9},
#  'N=O': {'frequency': 0.035,
#   'total_matches': 35,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 35},
#  '[NH3+]C1=CC=CC=C1': {'frequency': 0.019,
#   'total_matches': 19,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 19},
#  '[NH4+]': {'frequency': 0.036,
#   'total_matches': 36,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 36},
#  'CC1=NC2=CC=CC=C2[NH]1': {'frequency': 0.004,
#   'total_matches': 4,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 4},
#  '[NH3+][O-]': {'frequency': 0.036,
#   'total_matches': 36,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 36},
#  'NC1=CC=C2N=C[NH]C2=C1': {'frequency': 0.001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  '[OH-]': {'frequency': 0.036,
#   'total_matches': 36,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 36},
#  '[NH2+]=O': {'frequency': 0.034,
#   'total_matches': 34,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 34},
#  'CC1=NC=C[NH]1': {'frequency': 0.014,
#   'total_matches': 14,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 14},
#  '[NH3+]O': {'frequency': 0.036,
#   'total_matches': 39,
#   'avg_matches_per_mol': 1.0833333333333333,
#   'molecules_with_motif': 36},
#  'N[O-]': {'frequency': 0.036,
#   'total_matches': 36,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 36},
#  'C[NH3+]': {'frequency': 0.031,
#   'total_matches': 31,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 31},
#  'CCCCCCCl': {'frequency': 0.003,
#   'total_matches': 6,
#   'avg_matches_per_mol': 2.0,
#   'molecules_with_motif': 3},
#  'C1=CC2=CC=CC=C2C1': {'frequency': 0.002,
#   'total_matches': 2,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 2},
#  'N=N': {'frequency': 0.003,
#   'total_matches': 3,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 3},
#  'C=S': {'frequency': 0.007,
#   'total_matches': 7,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 7},
#  'CCCCC#N': {'frequency': 0.009,
#   'total_matches': 22,
#   'avg_matches_per_mol': 2.4444444444444446,
#   'molecules_with_motif': 9},
#  'CC1=CN=CC=N1': {'frequency': 0.005,
#   'total_matches': 6,
#   'avg_matches_per_mol': 1.2,
#   'molecules_with_motif': 5},
#  'NC1=NC=CN=C1': {'frequency': 0.001,
#   'total_matches': 2,
#   'avg_matches_per_mol': 2.0,
#   'molecules_with_motif': 1},
#  'C1=CN=CC=N1': {'frequency': 0.007,
#   'total_matches': 8,
#   'avg_matches_per_mol': 1.1428571428571428,
#   'molecules_with_motif': 7},
#  'NC1=CN=CC=N1': {'frequency': 0.001,
#   'total_matches': 2,
#   'avg_matches_per_mol': 2.0,
#   'molecules_with_motif': 1},
#  'C1=CCCCCC1': {'frequency': 0.001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'CC1CCCNCC1': {'frequency': 0.003,
#   'total_matches': 3,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 3},
#  'C1CNCC2(C1)CCNC2': {'frequency': 0.001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'CC1CCNC1': {'frequency': 0.02,
#   'total_matches': 28,
#   'avg_matches_per_mol': 1.4,
#   'molecules_with_motif': 20},
#  'OS': {'frequency': 0.001,
#   'total_matches': 6,
#   'avg_matches_per_mol': 6.0,
#   'molecules_with_motif': 1},
#  'CC1CCC(C)N1': {'frequency': 0.005,
#   'total_matches': 7,
#   'avg_matches_per_mol': 1.4,
#   'molecules_with_motif': 5},
#  'C1=COC=N1': {'frequency': 0.008,
#   'total_matches': 8,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 8},
#  'CC1=NC=CO1': {'frequency': 0.004,
#   'total_matches': 4,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 4},
#  'NC1=CC=CN=N1': {'frequency': 0.003,
#   'total_matches': 3,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 3},
#  'C1=CC=NN=C1': {'frequency': 0.007,
#   'total_matches': 7,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 7},
#  'C1=CN=NC=C1': {'frequency': 0.007,
#   'total_matches': 7,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 7},
#  'NC1=NN=CC=C1': {'frequency': 0.003,
#   'total_matches': 3,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 3},
#  'C1=CC2=C(C=CC=C2)NC1': {'frequency': 0.001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'CC1C=CC2=CC=CC=C2N1': {'frequency': 0.001,
#   'total_matches': 2,
#   'avg_matches_per_mol': 2.0,
#   'molecules_with_motif': 1},
#  'C1=CC2=CC=CC=C2NC1': {'frequency': 0.001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'C1=CCCC1': {'frequency': 0.01,
#   'total_matches': 10,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 10},
#  'C1=NCNN1': {'frequency': 0.011,
#   'total_matches': 11,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 11},
#  'NCS': {'frequency': 0.016,
#   'total_matches': 19,
#   'avg_matches_per_mol': 1.1875,
#   'molecules_with_motif': 16},
#  'C1OC2CC3CC1C2C3': {'frequency': 0.001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'C1CC2CCOC2C1': {'frequency': 0.001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'CC1CC2CCC1C2': {'frequency': 0.004,
#   'total_matches': 4,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 4},
#  'C1CCCOCC1': {'frequency': 0.005,
#   'total_matches': 6,
#   'avg_matches_per_mol': 1.2,
#   'molecules_with_motif': 5},
#  'C1CC2CCC1C2': {'frequency': 0.005,
#   'total_matches': 5,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 5},
#  'CC1CCOC1': {'frequency': 0.013,
#   'total_matches': 18,
#   'avg_matches_per_mol': 1.3846153846153846,
#   'molecules_with_motif': 13},
#  'OC1CCCC1': {'frequency': 0.011,
#   'total_matches': 16,
#   'avg_matches_per_mol': 1.4545454545454546,
#   'molecules_with_motif': 11},
#  'OC1CC2CCC1C2': {'frequency': 0.003,
#   'total_matches': 4,
#   'avg_matches_per_mol': 1.3333333333333333,
#   'molecules_with_motif': 3},
#  'CC1CCCC(C)C1': {'frequency': 0.021,
#   'total_matches': 39,
#   'avg_matches_per_mol': 1.8571428571428572,
#   'molecules_with_motif': 21},
#  'C1CC2COC(C1)C2': {'frequency': 0.001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'OC1=NC=CC=C1': {'frequency': 0.007,
#   'total_matches': 7,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 7},
#  'OC1=CC=CC=N1': {'frequency': 0.007,
#   'total_matches': 7,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 7},
#  'CC1CCNCC1': {'frequency': 0.018,
#   'total_matches': 18,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 18},
#  'C=CO': {'frequency': 0.014,
#   'total_matches': 17,
#   'avg_matches_per_mol': 1.2142857142857142,
#   'molecules_with_motif': 14},
#  'C1=CC2=C(C=C1)NCCC2': {'frequency': 0.003,
#   'total_matches': 3,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 3},
#  'C1=CC=C2NCCCC2=C1': {'frequency': 0.003,
#   'total_matches': 3,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 3},
#  'CC1=CC=C[NH]1': {'frequency': 0.015,
#   'total_matches': 18,
#   'avg_matches_per_mol': 1.2,
#   'molecules_with_motif': 15},
#  'CN1C=CC=C1': {'frequency': 0.012,
#   'total_matches': 12,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 12},
#  'NC1=CC=NC=N1': {'frequency': 0.006,
#   'total_matches': 6,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 6},
#  'CC1=CN=CN=C1': {'frequency': 0.009,
#   'total_matches': 9,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 9},
#  'NC1=NC=NC=C1': {'frequency': 0.006,
#   'total_matches': 6,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 6},
#  'SC1=CC=CC=C1': {'frequency': 0.016,
#   'total_matches': 16,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 16},
#  'CC1=N[NH]C=N1': {'frequency': 0.006,
#   'total_matches': 7,
#   'avg_matches_per_mol': 1.1666666666666667,
#   'molecules_with_motif': 6},
#  'CN1C=NN=C1': {'frequency': 0.007,
#   'total_matches': 7,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 7},
#  'C1=NN=C[NH]1': {'frequency': 0.014,
#   'total_matches': 15,
#   'avg_matches_per_mol': 1.0714285714285714,
#   'molecules_with_motif': 14},
#  'SC1=NC=N[NH]1': {'frequency': 0.009,
#   'total_matches': 9,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 9},
#  'CC1=NC=N[NH]1': {'frequency': 0.006,
#   'total_matches': 7,
#   'avg_matches_per_mol': 1.1666666666666667,
#   'molecules_with_motif': 6},
#  'SC1=NN=C[NH]1': {'frequency': 0.009,
#   'total_matches': 9,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 9},
#  'C1=N[NH]C=N1': {'frequency': 0.014,
#   'total_matches': 15,
#   'avg_matches_per_mol': 1.0714285714285714,
#   'molecules_with_motif': 14},
#  'CC1=NN=C[NH]1': {'frequency': 0.006,
#   'total_matches': 7,
#   'avg_matches_per_mol': 1.1666666666666667,
#   'molecules_with_motif': 6},
#  'SC1=N[NH]C=N1': {'frequency': 0.009,
#   'total_matches': 9,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 9},
#  'CCCCCS': {'frequency': 0.011,
#   'total_matches': 17,
#   'avg_matches_per_mol': 1.5454545454545454,
#   'molecules_with_motif': 11},
#  'C1CNCSC1': {'frequency': 0.001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'CBr': {'frequency': 0.009,
#   'total_matches': 9,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 9},
#  'Br': {'frequency': 0.01,
#   'total_matches': 10,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 10},
#  'CCBr': {'frequency': 0.007,
#   'total_matches': 9,
#   'avg_matches_per_mol': 1.2857142857142858,
#   'molecules_with_motif': 7},
#  'NC1=C[NH]C=N1': {'frequency': 0.004,
#   'total_matches': 4,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 4},
#  'C1=CC=C(C2=C[NH]C=N2)C=C1': {'frequency': 0.002,
#   'total_matches': 2,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 2},
#  'C1=CC=C(C2=CN=C[NH]2)C=C1': {'frequency': 0.002,
#   'total_matches': 2,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 2},
#  'CC1=CSC=C1': {'frequency': 0.005,
#   'total_matches': 5,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 5},
#  'CC1=CC(C2=CC=CC=C2)=N[NH]1': {'frequency': 0.001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'C1=CC=C(C2=N[NH]C=C2)C=C1': {'frequency': 0.002,
#   'total_matches': 2,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 2},
#  'C1=CC=C(C2=CC=N[NH]2)C=C1': {'frequency': 0.002,
#   'total_matches': 2,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 2},
#  'CC1=N[NH]C(C2=CC=CC=C2)=C1': {'frequency': 0.001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'CN1C=CC(C2=CC=CC=C2)=N1': {'frequency': 0.001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'NC1=C[NH]N=C1': {'frequency': 0.01,
#   'total_matches': 10,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 10},
#  'C1=CC(N2CCNCC2)=NN=C1': {'frequency': 0.001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'C1CNCCN1': {'frequency': 0.012,
#   'total_matches': 12,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 12},
#  'CN1CCNCC1': {'frequency': 0.011,
#   'total_matches': 14,
#   'avg_matches_per_mol': 1.2727272727272727,
#   'molecules_with_motif': 11},
#  'C1=CN=NC(N2CCNCC2)=C1': {'frequency': 0.001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'C1=CCCN=C1': {'frequency': 0.001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'CCCF': {'frequency': 0.022,
#   'total_matches': 85,
#   'avg_matches_per_mol': 3.8636363636363638,
#   'molecules_with_motif': 22},
#  'C1=CCCC=C1': {'frequency': 0.007,
#   'total_matches': 7,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 7},
#  'C1CNNC1': {'frequency': 0.005,
#   'total_matches': 5,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 5},
#  'C1=NCCCN1': {'frequency': 0.002,
#   'total_matches': 2,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 2},
#  'C1=CN=CC1': {'frequency': 0.001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'OC1=CC=N[NH]1': {'frequency': 0.003,
#   'total_matches': 3,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 3},
#  'C1=CC2=C(C=C1)CCC2': {'frequency': 0.007,
#   'total_matches': 7,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 7},
#  'C1=CC=C2CCCC2=C1': {'frequency': 0.007,
#   'total_matches': 7,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 7},
#  'OC1=CC=C2CCCC2=C1': {'frequency': 0.002,
#   'total_matches': 2,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 2},
#  'CC1=CC=C2CCCC2=C1': {'frequency': 0.003,
#   'total_matches': 4,
#   'avg_matches_per_mol': 1.3333333333333333,
#   'molecules_with_motif': 3},
#  'CCCCCCS': {'frequency': 0.006,
#   'total_matches': 10,
#   'avg_matches_per_mol': 1.6666666666666667,
#   'molecules_with_motif': 6},
#  'C1=CSC=N1': {'frequency': 0.016,
#   'total_matches': 16,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 16},
#  'CC1=CN=CS1': {'frequency': 0.004,
#   'total_matches': 4,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 4},
#  'CC1=CSC=N1': {'frequency': 0.011,
#   'total_matches': 11,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 11},
#  'N=C1[NH]C=CS1': {'frequency': 0.001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'O=S': {'frequency': 0.009,
#   'total_matches': 15,
#   'avg_matches_per_mol': 1.6666666666666667,
#   'molecules_with_motif': 9},
#  'NS': {'frequency': 0.004,
#   'total_matches': 4,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 4},
#  'NC=CN': {'frequency': 0.005,
#   'total_matches': 6,
#   'avg_matches_per_mol': 1.2,
#   'molecules_with_motif': 5},
#  'NC1=NC=CC=C1': {'frequency': 0.013,
#   'total_matches': 13,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 13},
#  'CC1=CC=CN=C1': {'frequency': 0.026,
#   'total_matches': 26,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 26},
#  'NC1=CC=CC=N1': {'frequency': 0.013,
#   'total_matches': 13,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 13},
#  'C#CC#C': {'frequency': 0.001,
#   'total_matches': 2,
#   'avg_matches_per_mol': 2.0,
#   'molecules_with_motif': 1},
#  'C#CC#CC': {'frequency': 0.001,
#   'total_matches': 3,
#   'avg_matches_per_mol': 3.0,
#   'molecules_with_motif': 1},
#  'C1=CCOC1': {'frequency': 0.001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'CC1C=CCO1': {'frequency': 0.001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'C1=NSN=C1': {'frequency': 0.001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'C1=CC2=NSN=C2C=C1': {'frequency': 0.001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'CC1CNCCO1': {'frequency': 0.005,
#   'total_matches': 6,
#   'avg_matches_per_mol': 1.2,
#   'molecules_with_motif': 5},
#  'C1COCCN1': {'frequency': 0.011,
#   'total_matches': 11,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 11},
#  'CN1CCOCC1': {'frequency': 0.008,
#   'total_matches': 8,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 8},
#  'CC1COCCN1': {'frequency': 0.004,
#   'total_matches': 6,
#   'avg_matches_per_mol': 1.5,
#   'molecules_with_motif': 4},
#  'CC1=C[NH]C2=CC=CC=C12': {'frequency': 0.003,
#   'total_matches': 3,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 3},
#  'C1=CC2=C(C=C1)[NH]C=C2': {'frequency': 0.008,
#   'total_matches': 8,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 8},
#  'C1=CC=C2[NH]C=CC2=C1': {'frequency': 0.008,
#   'total_matches': 8,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 8},
#  'C1=CCN(C2=CC=CC=C2)C1': {'frequency': 0.001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'C1=CCNC1': {'frequency': 0.001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'NC1=CSC=C1': {'frequency': 0.001,
#   'total_matches': 2,
#   'avg_matches_per_mol': 2.0,
#   'molecules_with_motif': 1},
#  'CC1=CC=CNC1': {'frequency': 0.003,
#   'total_matches': 3,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 3},
#  'C1=CN=C2N=CN=CC2=C1': {'frequency': 0.001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'C1=CC2=CN=CN=C2N=C1': {'frequency': 0.001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'OC1=NC=CC=N1': {'frequency': 0.002,
#   'total_matches': 2,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 2},
#  'CC1=CN=N[NH]1': {'frequency': 0.004,
#   'total_matches': 5,
#   'avg_matches_per_mol': 1.25,
#   'molecules_with_motif': 4},
#  'C1=C[NH]N=N1': {'frequency': 0.005,
#   'total_matches': 5,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 5},
#  'C1=N[NH]N=C1': {'frequency': 0.005,
#   'total_matches': 5,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 5},
#  'CN1C=CN=N1': {'frequency': 0.004,
#   'total_matches': 4,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 4},
#  'CC1=C[NH]N=N1': {'frequency': 0.004,
#   'total_matches': 5,
#   'avg_matches_per_mol': 1.25,
#   'molecules_with_motif': 4},
#  'CC1=CCCCC1': {'frequency': 0.006,
#   'total_matches': 7,
#   'avg_matches_per_mol': 1.1666666666666667,
#   'molecules_with_motif': 6},
#  'C1=CNCC(C2=CC=CC=C2)=C1': {'frequency': 0.001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'C1=CC=C2OCOC2=C1': {'frequency': 0.001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'OC1=CC=C2OCOC2=C1': {'frequency': 0.001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'OC1=CC2=C(C=C1)OCO2': {'frequency': 0.001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'CC1=CC=C2OCOC2=C1': {'frequency': 0.001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'C1=CC2=C(C=C1)OCO2': {'frequency': 0.001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'CC1=CC2=C(C=C1)OCO2': {'frequency': 0.001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'C1=CN=CNC1': {'frequency': 0.001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'C1=NCNC1': {'frequency': 0.001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'CC1=CN=CNC1': {'frequency': 0.001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'NC1=NC=CCN1': {'frequency': 0.001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'C1=CC=C(C2=NCNC2)C=C1': {'frequency': 0.001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'OO': {'frequency': 0.002,
#   'total_matches': 2,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 2},
#  'FC1CCCCC1': {'frequency': 0.003,
#   'total_matches': 6,
#   'avg_matches_per_mol': 2.0,
#   'molecules_with_motif': 3},
#  'C1=CC2=C(C=C1)NCNC2': {'frequency': 0.002,
#   'total_matches': 2,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 2},
#  'C1=CC=C2NCNCC2=C1': {'frequency': 0.002,
#   'total_matches': 2,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 2},
#  'C1=NCCN1': {'frequency': 0.007,
#   'total_matches': 7,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 7},
#  'CC1CNC=N1': {'frequency': 0.003,
#   'total_matches': 4,
#   'avg_matches_per_mol': 1.3333333333333333,
#   'molecules_with_motif': 3},
#  'C1CSCS1': {'frequency': 0.001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'C1CC2NCCOC2C1': {'frequency': 0.001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'NN1CCCC1': {'frequency': 0.002,
#   'total_matches': 2,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 2},
#  'CC1=CC=NC=C1': {'frequency': 0.013,
#   'total_matches': 13,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 13},
#  'C1=N[NH]C2=C1CCCC2': {'frequency': 0.003,
#   'total_matches': 3,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 3},
#  'C1=C2CCCCC2=N[NH]1': {'frequency': 0.003,
#   'total_matches': 3,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 3},
#  'CN1N=CC2=C1CCCC2': {'frequency': 0.001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'CC1=CC=C(C2=CC=CC=C2)O1': {'frequency': 0.001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'C1=CC=C(C2=CC=CO2)C=C1': {'frequency': 0.001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'C1=NCCCC1': {'frequency': 0.005,
#   'total_matches': 6,
#   'avg_matches_per_mol': 1.2,
#   'molecules_with_motif': 5},
#  'C1=NC2=C(C=N1)N=C[NH]2': {'frequency': 0.002,
#   'total_matches': 2,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 2},
#  'C1=NC=C2[NH]C=NC2=N1': {'frequency': 0.002,
#   'total_matches': 2,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 2},
#  'C1=NC2=C(C=N1)[NH]C=N2': {'frequency': 0.002,
#   'total_matches': 2,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 2},
#  'C1=NC=C2N=C[NH]C2=N1': {'frequency': 0.002,
#   'total_matches': 2,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 2},
#  'C1=CC=C(N2C=CC=C2)C=C1': {'frequency': 0.001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'CC1=CN(C2=CC=CC=C2)C=C1': {'frequency': 0.001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'C1CSCCN1': {'frequency': 0.002,
#   'total_matches': 2,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 2},
#  'CC1=NC=NO1': {'frequency': 0.006,
#   'total_matches': 6,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 6},
#  'C1=NOC=N1': {'frequency': 0.006,
#   'total_matches': 6,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 6},
#  'C1=NC(C2CCCC2)=NO1': {'frequency': 0.001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'CC1=NOC=N1': {'frequency': 0.006,
#   'total_matches': 6,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 6},
#  'C1=CCC=CC1': {'frequency': 0.005,
#   'total_matches': 5,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 5},
#  'C=CS': {'frequency': 0.006,
#   'total_matches': 8,
#   'avg_matches_per_mol': 1.3333333333333333,
#   'molecules_with_motif': 6},
#  'C=CSC': {'frequency': 0.006,
#   'total_matches': 8,
#   'avg_matches_per_mol': 1.3333333333333333,
#   'molecules_with_motif': 6},
#  'C1CCSC1': {'frequency': 0.002,
#   'total_matches': 2,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 2},
#  'C1=CC=C(C2CCN2)C=C1': {'frequency': 0.001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'CC1CCN1': {'frequency': 0.001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'C1=CCOCC1': {'frequency': 0.001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'C1=NC2=CC=CC=C2CC1': {'frequency': 0.002,
#   'total_matches': 2,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 2},
#  'CC#CCO': {'frequency': 0.001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'C#CCO': {'frequency': 0.003,
#   'total_matches': 3,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 3},
#  'CC1=CCCC(C)C1': {'frequency': 0.002,
#   'total_matches': 2,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 2},
#  'CC1CC=CCC1': {'frequency': 0.006,
#   'total_matches': 10,
#   'avg_matches_per_mol': 1.6666666666666667,
#   'molecules_with_motif': 6},
#  'C1=CC2=CC=CC=C2CC1': {'frequency': 0.001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'C1=CN2N=NN=C2C=N1': {'frequency': 0.001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'C1=NN=N[NH]1': {'frequency': 0.006,
#   'total_matches': 6,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 6},
#  'OC1=CN=CC=N1': {'frequency': 0.004,
#   'total_matches': 4,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 4},
#  'C1=N[NH]N=N1': {'frequency': 0.006,
#   'total_matches': 6,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 6},
#  'CCCC=NN': {'frequency': 0.004,
#   'total_matches': 5,
#   'avg_matches_per_mol': 1.25,
#   'molecules_with_motif': 4},
#  'CCC=NN': {'frequency': 0.005,
#   'total_matches': 10,
#   'avg_matches_per_mol': 2.0,
#   'molecules_with_motif': 5},
#  'CC1=NOCC1': {'frequency': 0.003,
#   'total_matches': 3,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 3},
#  'C=NOC': {'frequency': 0.005,
#   'total_matches': 5,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 5},
#  'CC=NO': {'frequency': 0.014,
#   'total_matches': 21,
#   'avg_matches_per_mol': 1.5,
#   'molecules_with_motif': 14},
#  'C1CC2CCC1O2': {'frequency': 0.001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'C1=NOCC1': {'frequency': 0.003,
#   'total_matches': 3,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 3},
#  'OC1CCOC1': {'frequency': 0.002,
#   'total_matches': 3,
#   'avg_matches_per_mol': 1.5,
#   'molecules_with_motif': 2},
#  'CC1CCC(C)O1': {'frequency': 0.002,
#   'total_matches': 2,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 2},
#  'CC1CC(O)C(C)O1': {'frequency': 0.001,
#   'total_matches': 2,
#   'avg_matches_per_mol': 2.0,
#   'molecules_with_motif': 1},
# ...
#   'avg_matches_per_mol': 1.5,
#   'molecules_with_motif': 2},
#  'CCCCC[NH3+]': {'frequency': 0.001,
#   'total_matches': 3,
#   'avg_matches_per_mol': 3.0,
#   'molecules_with_motif': 1},
#  'CCCC[NH3+]': {'frequency': 0.002,
#   'total_matches': 4,
#   'avg_matches_per_mol': 2.0,
#   'molecules_with_motif': 2},
#  'NC1=CC=C2C=CC=CC2=N1': {'frequency': 0.001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'C1=NC=C2[NH]N=CC2=C1': {'frequency': 0.001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'CC1=CC=CC2=NC=CC=C12': {'frequency': 0.001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'C1=CC2=C(C=N1)[NH]N=C2': {'frequency': 0.001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'NC1=NC2=CC=CC=C2C=C1': {'frequency': 0.001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'C1NNCNN1': {'frequency': 0.001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'SC1=NC2=CC=CC=C2S1': {'frequency': 0.001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'SC1=NC=CS1': {'frequency': 0.002,
#   'total_matches': 2,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 2},
#  'C1=CC=C2SC=NC2=C1': {'frequency': 0.001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'C1=CC2=C(C=C1)SC=N2': {'frequency': 0.001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'C1CC2CCCC(C1)C2': {'frequency': 0.002,
#   'total_matches': 2,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 2},
#  'C1=CC=C(C2CCC2)C=C1': {'frequency': 0.001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'CC1=CC=CC2=CC=CC=C12': {'frequency': 0.002,
#   'total_matches': 2,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 2},
#  'CC1=COC=N1': {'frequency': 0.001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'C1=NOCC1C1=CC=CC=C1': {'frequency': 0.001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'CC1CCCC(C#N)C1': {'frequency': 0.001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'C1CC2CC1CN2': {'frequency': 0.001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'CC1=CN(C2=CC=CC=C2)N=C1': {'frequency': 0.001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'C1=CC=C(N2C=CC=N2)C=C1': {'frequency': 0.001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'C1=NSC=N1': {'frequency': 0.001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'CN1CCN(C2=CC=CC=C2)CC1': {'frequency': 0.002,
#   'total_matches': 2,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 2},
#  'C1=CC=C(N2CCNCC2)C=C1': {'frequency': 0.002,
#   'total_matches': 2,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 2},
#  'CC1=NC2=C(CCC2)S1': {'frequency': 0.001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'C1=NC2=C(CCC2)S1': {'frequency': 0.001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'CN1CNC2=CC=CC=C2C1': {'frequency': 0.001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'CC1=CC=C2N=CC=CC2=C1': {'frequency': 0.001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'OC1=CC=CC2=CC=CN=C12': {'frequency': 0.002,
#   'total_matches': 2,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 2},
#  'OC1=CC=C2CCCCC2=C1': {'frequency': 0.001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'C1=CC=C2CCNCCC2=C1': {'frequency': 0.001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'C1=CC2=C(C=C1)CCNCC2': {'frequency': 0.001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'C1=NCCNC1': {'frequency': 0.001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'CC1CNCCS1=O': {'frequency': 0.001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'O=S1CCNCC1': {'frequency': 0.001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'O=S1CCNC(C2=CC=CO2)C1': {'frequency': 0.001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'C1=COC(C2CSCCN2)=C1': {'frequency': 0.001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'CC1CNCCS1': {'frequency': 0.001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'C1=COC(C2CCCCO2)=C1': {'frequency': 0.001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'OC1=CC=CN=N1': {'frequency': 0.002,
#   'total_matches': 2,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 2},
#  'CC1=CC=C[NH+]=C1': {'frequency': 0.001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'C1=CC=[NH+]C=C1': {'frequency': 0.001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'C1CCCCNCCC1': {'frequency': 0.001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'C1=CC2=NN=CN2N=C1': {'frequency': 0.001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'C1=NC2=CC=CC=C2OC1': {'frequency': 0.001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'SC1=NC=CC=N1': {'frequency': 0.001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'CC1=CC=CC2=C1OCCO2': {'frequency': 0.001,
#   'total_matches': 2,
#   'avg_matches_per_mol': 2.0,
#   'molecules_with_motif': 1},
#  'C1=CC2=C(C=C1)OCCO2': {'frequency': 0.001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'C1=CC=C2OCCOC2=C1': {'frequency': 0.001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'NC1=NON=C1': {'frequency': 0.001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'CC1=NON=C1': {'frequency': 0.001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'C1=NON=C1': {'frequency': 0.001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'C1=CC=C2C(=C1)C=NC1=CC=NN12': {'frequency': 0.001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'CC1=C2N=CC=CN2N=C1': {'frequency': 0.001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'C1=CN2N=CC=C2N=C1': {'frequency': 0.002,
#   'total_matches': 2,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 2},
#  'C1CC2(CCN1)NCCO2': {'frequency': 0.001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'CC1=COC2=CC=CC=C12': {'frequency': 0.001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'C1=NCN=CC1': {'frequency': 0.003,
#   'total_matches': 3,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 3},
#  'C1=CC=C(C2=NN=CO2)C=C1': {'frequency': 0.001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'SC1=NN=CO1': {'frequency': 0.002,
#   'total_matches': 2,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 2},
#  'SC1=NN=C(C2=CC=CC=C2)O1': {'frequency': 0.001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'C1CCC2NCCCC2C1': {'frequency': 0.002,
#   'total_matches': 2,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 2},
#  'C1=COCO1': {'frequency': 0.001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'C1=CN=C(N2C=CC=N2)N=C1': {'frequency': 0.001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'C1=CC=C2CCC2=C1': {'frequency': 0.001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'C1CNCN1': {'frequency': 0.002,
#   'total_matches': 2,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 2},
#  'CC1CC2=CC=CC=C21': {'frequency': 0.001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'CC1=CC2=CC=CC=C2N=C1': {'frequency': 0.001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'FC1CCNCC1': {'frequency': 0.001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'OC1=NC2=CC=CC=C2[NH]1': {'frequency': 0.001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'CC1OC2CCOCC2O1': {'frequency': 0.001,
#   'total_matches': 2,
#   'avg_matches_per_mol': 2.0,
#   'molecules_with_motif': 1},
#  'C1CSCSC1': {'frequency': 0.001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'C1=CC(C2=CC=CC=C2)CCC1': {'frequency': 0.001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'C1=CC2=CC=NC=C2C=C1': {'frequency': 0.002,
#   'total_matches': 3,
#   'avg_matches_per_mol': 1.5,
#   'molecules_with_motif': 2},
#  'OC1=CC=CC2=CN=CC=C12': {'frequency': 0.001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'C1=CC=C2C=NC=CC2=C1': {'frequency': 0.002,
#   'total_matches': 3,
#   'avg_matches_per_mol': 1.5,
#   'molecules_with_motif': 2},
#  'C1=CCCCC=C1': {'frequency': 0.001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'C1=NC=NC(N2C=CN=C2)=C1': {'frequency': 0.001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'C1=CC(N2C=CN=C2)=NC=N1': {'frequency': 0.001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'C1=CC(C2CCCN2)=CC=N1': {'frequency': 0.001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'CC1NCCS1': {'frequency': 0.002,
#   'total_matches': 2,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 2},
#  'CC1CSCN1': {'frequency': 0.001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'C1CSCN1': {'frequency': 0.002,
#   'total_matches': 2,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 2},
#  'C1CC2CCCC(C1)N2': {'frequency': 0.001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'CN=C=S': {'frequency': 0.001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'N=C=S': {'frequency': 0.001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'C1CC2CCC1CO2': {'frequency': 0.001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'C1CNCCOC1': {'frequency': 0.001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'NC1=CC=C2[NH]C=CC2=C1': {'frequency': 0.001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'C1=NCCCCC1': {'frequency': 0.002,
#   'total_matches': 2,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 2},
#  'C1CCC(C2CCCC2)CC1': {'frequency': 0.001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'CC1CCC(C2CCCC2)CC1': {'frequency': 0.001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'FC1CC1': {'frequency': 0.001,
#   'total_matches': 5,
#   'avg_matches_per_mol': 5.0,
#   'molecules_with_motif': 1},
#  'C1=NC2=C(CCCC2)S1': {'frequency': 0.001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'CC1=NC2=C(CCCC2)S1': {'frequency': 0.001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'C1=CC=C(C2=NN=CC=N2)C=C1': {'frequency': 0.001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'CC1CCN(C2=CC=CC=C2)C1': {'frequency': 0.001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'OC1CNC1': {'frequency': 0.001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'OC1=NC2=CC=CC=C2O1': {'frequency': 0.001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'C1CCC2OCCC2C1': {'frequency': 0.001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'CC1=NC2=CC=NN2C=C1': {'frequency': 0.001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'C1=NC2=C(C=N1)CCNCC2': {'frequency': 0.001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'C1=NC=C2CCNCCC2=N1': {'frequency': 0.001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'CC1=CN2N=CC=C2N=C1': {'frequency': 0.001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'CN1C=CC=CC1': {'frequency': 0.001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'C1=CC2=CC=NN2C=C1': {'frequency': 0.001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'OC1CC=CCC1': {'frequency': 0.001,
#   'total_matches': 2,
#   'avg_matches_per_mol': 2.0,
#   'molecules_with_motif': 1},
#  'C1=CNOC1': {'frequency': 0.001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'C=CC[NH3+]': {'frequency': 0.001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'C1=NC2=CN=C[NH]C2=N1': {'frequency': 0.001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'C1=NC2=C[NH]C=NC2=N1': {'frequency': 0.001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  '[NH3+]CCO': {'frequency': 0.001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'C1=CC=C(C2=NC=NO2)C=C1': {'frequency': 0.001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'CC1=NOC(C2=CC=CC=C2)=N1': {'frequency': 0.001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'C1=NNNN1': {'frequency': 0.001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'NC1=NC=NC2=CC=CC=C12': {'frequency': 0.001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'C1=CC=C(C2=NOC=N2)C=C1': {'frequency': 0.001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'CC1=NC(C2=CC=CC=C2)=NO1': {'frequency': 0.001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'CC1CNCO1': {'frequency': 0.001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'C1=CC=C(N2CCOC2)C=C1': {'frequency': 0.001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'SCl': {'frequency': 0.001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'C1=NCSC1': {'frequency': 0.001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'C1=CC=C(N2CCOCC2)N=C1': {'frequency': 0.001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'C1=CN=C(N2CCOCC2)C=C1': {'frequency': 0.001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'NC1=CC=C(N2CCOCC2)N=C1': {'frequency': 0.001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'C1=COCCC1': {'frequency': 0.001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'CC1CCC=CO1': {'frequency': 0.001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'C#CCCO': {'frequency': 0.001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1},
#  'C1=CN=C(N2CCCCC2)N=C1': {'frequency': 0.001,
#   'total_matches': 1,
#   'avg_matches_per_mol': 1.0,
#   'molecules_with_motif': 1}}

# %%
motif_stats_smaller = {k: v for k, v in motif_stats.items() if v['frequency'] > 0.1}
print(f"Number of motifs with frequency > {min_motif_frequency}: {len(motif_stats_smaller)}")
motif_stats_smaller = {k: v for k, v in motif_stats_smaller.items() if Chem.MolFromSmiles(k).GetNumAtoms() >= min_motif_size}
print(f"Number of motifs with frequency > {min_motif_frequency} and num atoms >= {min_motif_size}: {len(motif_stats_smaller)}")
motif_stats_smaller
# Out:
# Number of motifs with frequency > 0.1: 35
# Number of motifs with frequency > 0.1 and num atoms >= 2: 31
# {'CC': {'frequency': 0.975,
#   'total_matches': 5386,
#   'avg_matches_per_mol': 5.524102564102564,
#   'molecules_with_motif': 975},
#  'CN': {'frequency': 0.704,
#   'total_matches': 1811,
#   'avg_matches_per_mol': 2.5724431818181817,
#   'molecules_with_motif': 704},
#  'CCN': {'frequency': 0.617,
#   'total_matches': 1659,
#   'avg_matches_per_mol': 2.6888168557536467,
#   'molecules_with_motif': 617},
#  'CCCCC': {'frequency': 0.413,
#   'total_matches': 2212,
#   'avg_matches_per_mol': 5.3559322033898304,
#   'molecules_with_motif': 413},
#  'CCCCCC': {'frequency': 0.256,
#   'total_matches': 1311,
#   'avg_matches_per_mol': 5.12109375,
#   'molecules_with_motif': 256},
#  'CCCN': {'frequency': 0.462,
#   'total_matches': 1123,
#   'avg_matches_per_mol': 2.430735930735931,
#   'molecules_with_motif': 462},
#  'CCCC': {'frequency': 0.582,
#   'total_matches': 3076,
#   'avg_matches_per_mol': 5.285223367697594,
#   'molecules_with_motif': 582},
#  'CCC': {'frequency': 0.815,
#   'total_matches': 4284,
#   'avg_matches_per_mol': 5.256441717791411,
#   'molecules_with_motif': 815},
#  'O=CO': {'frequency': 0.181,
#   'total_matches': 207,
#   'avg_matches_per_mol': 1.143646408839779,
#   'molecules_with_motif': 181},
#  'C=O': {'frequency': 0.358,
#   'total_matches': 445,
#   'avg_matches_per_mol': 1.2430167597765363,
#   'molecules_with_motif': 358},
#  'NC=O': {'frequency': 0.112,
#   'total_matches': 127,
#   'avg_matches_per_mol': 1.1339285714285714,
#   'molecules_with_motif': 112},
#  'CCO': {'frequency': 0.528,
#   'total_matches': 1159,
#   'avg_matches_per_mol': 2.195075757575758,
#   'molecules_with_motif': 528},
#  'C1=CC=CC=C1': {'frequency': 0.38,
#   'total_matches': 410,
#   'avg_matches_per_mol': 1.0789473684210527,
#   'molecules_with_motif': 380},
#  'CO': {'frequency': 0.596,
#   'total_matches': 1261,
#   'avg_matches_per_mol': 2.115771812080537,
#   'molecules_with_motif': 596},
#  'CC=O': {'frequency': 0.326,
#   'total_matches': 475,
#   'avg_matches_per_mol': 1.4570552147239264,
#   'molecules_with_motif': 326},
#  'NCCO': {'frequency': 0.147,
#   'total_matches': 180,
#   'avg_matches_per_mol': 1.2244897959183674,
#   'molecules_with_motif': 147},
#  'CC1=CC=CC=C1': {'frequency': 0.296,
#   'total_matches': 441,
#   'avg_matches_per_mol': 1.489864864864865,
#   'molecules_with_motif': 296},
#  'COC': {'frequency': 0.298,
#   'total_matches': 379,
#   'avg_matches_per_mol': 1.2718120805369129,
#   'molecules_with_motif': 298},
#  'C=N': {'frequency': 0.2,
#   'total_matches': 224,
#   'avg_matches_per_mol': 1.12,
#   'molecules_with_motif': 200},
#  'C=NC': {'frequency': 0.14,
#   'total_matches': 153,
#   'avg_matches_per_mol': 1.0928571428571427,
#   'molecules_with_motif': 140},
#  'N=CO': {'frequency': 0.117,
#   'total_matches': 130,
#   'avg_matches_per_mol': 1.1111111111111112,
#   'molecules_with_motif': 117},
#  'CC=N': {'frequency': 0.151,
#   'total_matches': 181,
#   'avg_matches_per_mol': 1.1986754966887416,
#   'molecules_with_motif': 151},
#  'C=CCC': {'frequency': 0.112,
#   'total_matches': 260,
#   'avg_matches_per_mol': 2.3214285714285716,
#   'molecules_with_motif': 112},
#  'C=C': {'frequency': 0.175,
#   'total_matches': 227,
#   'avg_matches_per_mol': 1.2971428571428572,
#   'molecules_with_motif': 175},
#  'CCCO': {'frequency': 0.383,
#   'total_matches': 906,
#   'avg_matches_per_mol': 2.3655352480417755,
#   'molecules_with_motif': 383},
#  'C=CC': {'frequency': 0.169,
#   'total_matches': 447,
#   'avg_matches_per_mol': 2.6449704142011834,
#   'molecules_with_motif': 169},
#  'CCCCO': {'frequency': 0.259,
#   'total_matches': 656,
#   'avg_matches_per_mol': 2.5328185328185326,
#   'molecules_with_motif': 259},
#  'CCCCCO': {'frequency': 0.172,
#   'total_matches': 466,
#   'avg_matches_per_mol': 2.7093023255813953,
#   'molecules_with_motif': 172},
#  'CCC=O': {'frequency': 0.208,
#   'total_matches': 372,
#   'avg_matches_per_mol': 1.7884615384615385,
#   'molecules_with_motif': 208},
#  'CS': {'frequency': 0.106,
#   'total_matches': 205,
#   'avg_matches_per_mol': 1.9339622641509433,
#   'molecules_with_motif': 106},
#  'NC1=CC=CC=C1': {'frequency': 0.125,
#   'total_matches': 140,
#   'avg_matches_per_mol': 1.12,
#   'molecules_with_motif': 125}}

# %%
def visualize_motif_frequency(motif_stats, top_n=20):
    for key in motif_stats.keys():
        motif_stats[key]["smiles"] = key
    
    sorted_motifs = sorted(motif_stats.items(), 
                          key=lambda x: x[1]['frequency'], 
                          reverse=True)[:top_n]
    
    motifs = [item[0] for item in sorted_motifs]
    frequencies = [item[1]['frequency'] * 100 for item in sorted_motifs]
    
    plt.figure(figsize=(15, 10))
    
    # Create subplot for frequency
    plt.subplot(2, 1, 1)
    bars = plt.bar(range(len(motifs)), frequencies, color='skyblue', alpha=0.7)
    plt.ylabel('Frequency (%)')
    plt.title(f'Most Frequent Motifs in ZINC Dataset (dataset size = {num_molecules})')
    plt.xticks(range(len(motifs)), [motif_stats[motif]['smiles'] for motif in motifs], rotation=45)
    
    for i, bar in enumerate(bars):
        height = bar.get_height()
        plt.text(bar.get_x() + bar.get_width()/2., height + 0.5,
                f'{frequencies[i]:.1f}%', ha='center', va='bottom', fontsize=8)
    
    # Create subplot for total matches
    total_matches = [item[1]['total_matches'] for item in sorted_motifs]
    plt.subplot(2, 1, 2)
    bars2 = plt.bar(range(len(motifs)), total_matches, color='lightcoral', alpha=0.7)
    plt.ylabel('Total Matches')
    plt.title(f'Total Matches for Most Frequent Motifs (dataset size = {num_molecules})')
    plt.xticks(range(len(motifs)), [motif_stats[motif]['smiles'] for motif in motifs], rotation=45)
    
    for i, bar in enumerate(bars2):
        height = bar.get_height()
        plt.text(bar.get_x() + bar.get_width()/2., height + 5,
                f'{total_matches[i]}', ha='center', va='bottom', fontsize=8)
    
    plt.tight_layout()
    plt.show()
    
visualize_motif_frequency(motif_stats_smaller, top_n=20)

# %%
num_matches = [motif_stats_smaller[key]["total_matches"] for key in motif_stats_smaller.keys()]
print(f"Total number of matches: {sum(num_matches)}")
# Out:
# Total number of matches: 30313

# %%
list(motif_stats_smaller.keys())
# Out:
# ['CC',
#  'CN',
#  'CCN',
#  'CCCCC',
#  'CCCCCC',
#  'CCCN',
#  'CCCC',
#  'CCC',
#  'O=CO',
#  'C=O',
#  'NC=O',
#  'CCO',
#  'C1=CC=CC=C1',
#  'CO',
#  'CC=O',
#  'NCCO',
#  'CC1=CC=CC=C1',
#  'COC',
#  'C=N',
#  'C=NC',
#  'N=CO',
#  'CC=N',
#  'C=CCC',
#  'C=C',
#  'CCCO',
#  'C=CC',
#  'CCCCO',
#  'CCCCCO',
#  'CCC=O',
#  'CS',
#  'NC1=CC=CC=C1']

# %%
manually_cleaned_motifs = [
    # 'CC',
    # 'CN',
    # 'CCN',
    # 'CCCCC',
    # 'CCCCCC',
    # 'CCCN',
    # 'CCCC',
    # 'CCC',
    'O=CO',
    'C=O',
    'NC=O',
    # 'CCO',
    'C1=CC=CC=C1',
    # 'CO',
    # 'CC=O',
    'NCCO',
    # 'CC1=CC=CC=C1',
    'COC',
    'C=N',
    # 'C=NC',
    'N=CO',
    # 'CC=N',
    # 'C=CCC',
    'C=C',
    # 'CCCO',
    # 'C=CC',
    # 'CCCCO',
    # 'CCCCCO',
    # 'CCC=O',
    # 'CS',
    'NC1=CC=CC=C1'
    ]
len(manually_cleaned_motifs)
# Out:
# 10

# %%
manually_cleaned_stats = {k: v for k, v in motif_stats.items() if k in manually_cleaned_motifs}
manually_cleaned_stats
# Out:
# {'O=CO': {'frequency': 0.181,
#   'total_matches': 207,
#   'avg_matches_per_mol': 1.143646408839779,
#   'molecules_with_motif': 181,
#   'smiles': 'O=CO'},
#  'C=O': {'frequency': 0.358,
#   'total_matches': 445,
#   'avg_matches_per_mol': 1.2430167597765363,
#   'molecules_with_motif': 358,
#   'smiles': 'C=O'},
#  'NC=O': {'frequency': 0.112,
#   'total_matches': 127,
#   'avg_matches_per_mol': 1.1339285714285714,
#   'molecules_with_motif': 112,
#   'smiles': 'NC=O'},
#  'C1=CC=CC=C1': {'frequency': 0.38,
#   'total_matches': 410,
#   'avg_matches_per_mol': 1.0789473684210527,
#   'molecules_with_motif': 380,
#   'smiles': 'C1=CC=CC=C1'},
#  'NCCO': {'frequency': 0.147,
#   'total_matches': 180,
#   'avg_matches_per_mol': 1.2244897959183674,
#   'molecules_with_motif': 147,
#   'smiles': 'NCCO'},
#  'COC': {'frequency': 0.298,
#   'total_matches': 379,
#   'avg_matches_per_mol': 1.2718120805369129,
#   'molecules_with_motif': 298,
#   'smiles': 'COC'},
#  'C=N': {'frequency': 0.2,
#   'total_matches': 224,
#   'avg_matches_per_mol': 1.12,
#   'molecules_with_motif': 200,
#   'smiles': 'C=N'},
#  'N=CO': {'frequency': 0.117,
#   'total_matches': 130,
#   'avg_matches_per_mol': 1.1111111111111112,
#   'molecules_with_motif': 117,
#   'smiles': 'N=CO'},
#  'C=C': {'frequency': 0.175,
#   'total_matches': 227,
#   'avg_matches_per_mol': 1.2971428571428572,
#   'molecules_with_motif': 175,
#   'smiles': 'C=C'},
#  'NC1=CC=CC=C1': {'frequency': 0.125,
#   'total_matches': 140,
#   'avg_matches_per_mol': 1.12,
#   'molecules_with_motif': 125,
#   'smiles': 'NC1=CC=CC=C1'}}

# %%
num_matches = [manually_cleaned_stats[key]["total_matches"] for key in manually_cleaned_stats.keys()]
print(f"Total number of matches: {sum(num_matches)}")
# Out:
# Total number of matches: 2469

# %%
visualize_motif_frequency(manually_cleaned_stats, top_n=20)

# %%
num_matches = [manually_cleaned_stats[key]["total_matches"] for key in manually_cleaned_stats.keys()]
print(f"Total number of matches: {sum(num_matches)}")
print(f"Total number of motifs: {len(manually_cleaned_stats)}")
# Out:
# Total number of matches: 2469
# Total number of motifs: 10

# %%
def plot_motif_dualbars(
    motif_stats,
    num_molecules,
    top_n=20,
):
    fig_width_in=6.0
    height_per_bar_in=0.32
    outfile="motifs_dualbars.pdf"
    palette=("#0072B2", "#D55E00")

    figure_height = max(1.6, height_per_bar_in * max(3, top_n) + 0.6)
    with mpl.rc_context({
        "figure.figsize": (fig_width_in, figure_height),
        "figure.dpi": 150,
        "savefig.dpi": 600,
        "savefig.bbox": "tight",
        "savefig.pad_inches": 0.02,
        "font.size": 11,
        "axes.titlesize": 11,
        "axes.labelsize": 11,
        "legend.fontsize": 11,
        "xtick.labelsize": 11,
        "ytick.labelsize": 11,
        "font.family": "serif",
        "axes.linewidth": 0.8,
        "grid.linewidth": 0.4,
        "grid.alpha": 0.25,
        "grid.linestyle": "--",
        "legend.frameon": False,
        "pdf.fonttype": 42,
        "ps.fonttype": 42,
    }):
        rows = []
        for k, v in motif_stats.items():
            f = float(v["frequency"])
            pct = 100.0 * f
            n = v["total_matches"]
            rows.append((k, pct, n))

        rows.sort(key=lambda t: t[2], reverse=True)
        rows = rows[:top_n]

        motifs = [r[0] for r in rows][::-1]
        freq_pct = np.array([r[1] for r in rows], dtype=float)[::-1]
        counts = np.array([r[2] for r in rows], dtype=int)[::-1]

        y_labels = motifs

        freq_color, count_color = palette
        fig, ax_pct = plt.subplots()

        y = np.arange(len(motifs))
        bar_h = 0.42  # group height ~0.84

        b1 = ax_pct.barh(
            y - bar_h/2, freq_pct, height=bar_h, label="Frequency (%)",
            color=freq_color, alpha=0.9, edgecolor="none", zorder=3
        )
        ax_pct.set_xlabel("Frequency (%)")
        ax_pct.set_yticks(y)
        ax_pct.set_yticklabels(y_labels)
        ax_pct.invert_yaxis()
        ax_pct.xaxis.set_major_locator(MaxNLocator(5))
        ax_pct.xaxis.set_major_formatter(PercentFormatter(xmax=100, decimals=0))
        ax_pct.grid(axis="x", zorder=0)

        ax_cnt = ax_pct.twiny()
        b2 = ax_cnt.barh(
            y + bar_h/2, counts, height=bar_h, label="Total matches (n)",
            color=count_color, alpha=0.9, edgecolor="none", zorder=2
        )
        ax_cnt.set_xlabel("Total matches (n)")
        ax_cnt.xaxis.set_major_locator(MaxNLocator(5, integer=True))
        ax_cnt.xaxis.set_major_formatter(FuncFormatter(lambda x, pos: f"{int(x):,}"))

        legend_handles = [
            Patch(facecolor=freq_color, edgecolor="none", label="Frequency (%)"),
            Patch(facecolor=count_color, edgecolor="none", label="Total matches (n)"),
        ]
        ax_pct.legend(handles=legend_handles, loc="upper right")

        # ax_pct.set_title(f"The {len(motifs)} most frequent motifs in first {num_molecules:,} molecules of PCQM4Mv2")

        for spine in ["top", "right"]:
            ax_pct.spines[spine].set_visible(False)
        ax_cnt.spines["bottom"].set_visible(False)  # avoid double baseline

        fig.tight_layout()
        fig.savefig(outfile)
        return fig, (ax_pct, ax_cnt)

fig, ax = plot_motif_dualbars(manually_cleaned_stats, num_molecules=num_molecules, top_n=20)
